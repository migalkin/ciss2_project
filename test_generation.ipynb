# %%
import json
import nltk
nltk.download('punkt')
import torch
from models import InferSent
import numpy as np
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\erazu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import spacy
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.neighbors import NearestNeighbors
import numpy as np
import pickle as pkl

# %% [markdown]
# ### Loading test data

# %%
test_labels = json.load(open('data/data_test.json', 'r', encoding='utf-8'))

# %%
all_labels = []
for key in list(test_labels.keys()):
    curr_labels = []
    for key1 in ['label', 'synonyms']:
        if isinstance(test_labels[key][key1], list):
            curr_labels += test_labels[key][key1]
        else:
            curr_labels += [test_labels[key][key1]]
        
    all_labels.append(curr_labels)

# %%
all_labels[:9]
# Out:
# [['applies to jurisdiction',
#   'of jurisdiction',
#   'linked to jurisdiction',
#   'belongs to jurisdiction',
#   'jurisdiction',
#   'country of jurisdiction',
#   'valid in jurisdiction',
#   'applies to territorial jurisdiction',
#   'applied to jurisdiction'],
#  ['member of political party',
#   'political party',
#   'party',
#   'member of',
#   'member of party',
#   'party membership'],
#  ['conferred by',
#   'awarded by',
#   'bestowed by',
#   'given by',
#   'granted by',
#   'presented by'],
#  ['donated by', 'given by', 'bestowed by', 'gift from', 'donation from'],
#  ['native language',
#   'first language',
#   'mother tongue',
#   'language native',
#   'L1 speaker of'],
#  ['manager/director', 'art director', 'manager', 'director'],
#  ['relative', 'family', 'family member', 'kinsman', 'relation'],
#  ['medical condition',
#   'disability',
#   'ailment',
#   'health problem',
#   'disorder',
#   'illness',
#   'disease',
#   'paralympic disability',
#   'health condition'],
#  ['product or material produced',
#   'material produced',
#   'produces',
#   'manufactures',
#   'makes',
#   'has product',
#   'product',
#   'maker of',
#   'manufacturer of',
#   'producer of',
#   'results in',
#   'creates',
#   'output',
#   'products',
#   'work produced',
#   'commodity']]

# %%
questions = [['Which jurisdiction does European Bank belong to ?', 'Which jurisdiction works in the United Kingdom ?'], ['Which party does Donald Trump belong to ?', 'What are main parties in the United Kingdom ?'],
['Who received the Oscar for Titanik ?',
'Who was awarded Nobel Prize in Physics in 1972 ?'],
['Which fund makes the largest donations to the British Cancer Research ?',
'Whose donations was the Carnegie Museum founded on ?'],
['What is the first language of Albert Einstein ?',
'What was Tolstai native spaker of ?']]

# %%
len(questions)
# Out:
# 5

# %%
all_labels[:5]
# Out:
# [['applies to jurisdiction',
#   'of jurisdiction',
#   'linked to jurisdiction',
#   'belongs to jurisdiction',
#   'jurisdiction',
#   'country of jurisdiction',
#   'valid in jurisdiction',
#   'applies to territorial jurisdiction',
#   'applied to jurisdiction'],
#  ['member of political party',
#   'political party',
#   'party',
#   'member of',
#   'member of party',
#   'party membership'],
#  ['conferred by',
#   'awarded by',
#   'bestowed by',
#   'given by',
#   'granted by',
#   'presented by'],
#  ['donated by', 'given by', 'bestowed by', 'gift from', 'donation from'],
#  ['native language',
#   'first language',
#   'mother tongue',
#   'language native',
#   'L1 speaker of']]

# %%
list(zip(all_labels[:5], questions))
# Out:
# [(['applies to jurisdiction',
#    'of jurisdiction',
#    'linked to jurisdiction',
#    'belongs to jurisdiction',
#    'jurisdiction',
#    'country of jurisdiction',
#    'valid in jurisdiction',
#    'applies to territorial jurisdiction',
#    'applied to jurisdiction'],
#   ['Which jurisdiction does European Bank belong to ?',
#    'Which jurisdiction works in the United Kingdom ?']),
#  (['member of political party',
#    'political party',
#    'party',
#    'member of',
#    'member of party',
#    'party membership'],
#   ['Which party does Donald Trump belong to ?',
#    'What are main parties in the United Kingdom ?']),
#  (['conferred by',
#    'awarded by',
#    'bestowed by',
#    'given by',
#    'granted by',
#    'presented by'],
#   ['Who received the Oscar for Titanik ?',
#    'Who was awarded Nobel Prize in Physics in 1972 ?']),
#  (['donated by', 'given by', 'bestowed by', 'gift from', 'donation from'],
#   ['Which fund makes the largest donations to the British Cancer Research ?',
#    'Whose donations was the Carnegie Museum founded on ?']),
#  (['native language',
#    'first language',
#    'mother tongue',
#    'language native',
#    'L1 speaker of'],
#   ['What is the first language of Albert Einstein ?',
#    'What was Tolstai native spaker of ?'])]

# %% [markdown]
# ### Infersent loading and processing

# %%
V = 2
MODEL_PATH = 'encoder/infersent%s.pkl' % V
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': V}
infersent = InferSent(params_model)
infersent.load_state_dict(torch.load(MODEL_PATH))
W2V_PATH = 'fastText/crawl-300d-2M.vec'
infersent.set_w2v_path(W2V_PATH)

# %% [markdown]
# ### Training data load and collecting all sentences together

# %%
training = json.load(open('data/dataset.json', 'r', encoding='utf-8'))

# %%
all_sents = []
for key in list(training.keys()):
    for key1 in ['labels', 'questions']:
        for element in training[key][key1]:
            all_sents.append(element)
print(len(all_sents))
# Out:
# 52849

# %%
for list_of_questions in questions:
    for question in list_of_questions:
        all_sents.append(question)
print(len(all_sents))
# Out:
# 52859

# %%
for list_of_labels in all_labels[:5]:
    for label in list_of_labels:
        all_sents.append(label)

# %%
len(all_sents)
# Out:
# 52921

# %% [markdown]
# ### Building vocab for all sentences and labels

# %%
infersent.build_vocab(all_sents, tokenize=True)
# Out:
# Found 24994(/38793) words with w2v vectors
# Vocab size : 24994

# %% [markdown]
# ### Getting tuples for test questions and first 5 test labels

# %%
tuples_with_labels = []
tuples_questions_labels = list(zip(all_labels[:5], questions))
for tuple_1 in tuples_questions_labels:
    embedding_labels = infersent.encode(tuple_1[0], tokenize=True)
    embedding_label_av = np.mean(embedding_labels, axis=0)
    #print(embedding_label_av.shape)
    embedding_quest = infersent.encode(tuple_1[1], tokenize=True)
    print(embedding_quest.shape)
    tuples_with_labels.append((tuple_1[0], tuple_1[1], embedding_label_av, embedding_quest))
# Out:
# (2, 4096)
# (2, 4096)
# (2, 4096)
# (2, 4096)
# (2, 4096)

# %%
tuples_with_labels[0]
# Out:
# (['applies to jurisdiction',
#   'of jurisdiction',
#   'linked to jurisdiction',
#   'belongs to jurisdiction',
#   'jurisdiction',
#   'country of jurisdiction',
#   'valid in jurisdiction',
#   'applies to territorial jurisdiction',
#   'applied to jurisdiction'],
#  ['Which jurisdiction does European Bank belong to ?',
#   'Which jurisdiction works in the United Kingdom ?'],
#  array([ 0.00746889, -0.03260348,  0.02242357, ...,  0.00092162,
#         -0.05534602, -0.03559341], dtype=float32),
#  array([[ 0.00746889, -0.03840831, -0.01202221, ...,  0.03808134,
#           0.00890901, -0.01986518],
#         [ 0.00746889, -0.04294045,  0.0971196 , ...,  0.0226282 ,
#           0.01503134, -0.0214828 ]], dtype=float32))

# %% [markdown]
# ### Model and finding probs for each label index

# %%
class ZS_net(nn.Module):
        def __init__(self, question_emb_size):
            super(ZS_net, self).__init__()
            self.W = nn.Parameter(torch.nn.init.xavier_uniform_(torch.Tensor(question_emb_size, question_emb_size)).double())
            
        
        def forward(self, question_emb, label_emb):
            mult = torch.mm(question_emb, self.W)
            output = torch.bmm(mult.unsqueeze(1), label_emb.unsqueeze(2))
            return output

# %%
model = ZS_net(4096).float()
model.load_state_dict(torch.load('my_model.ckpt'))

# %%
all_classes = []
for tuple_1 in tuples_with_labels:
    all_classes.append(tuple_1[2])
    
all_questions = []
for tuple_1 in tuples_with_labels:
    all_questions+=list(tuple_1[3])

# %%
for quest_number in range(len(all_questions)):
    for class_number in range(len(all_classes)):
        sim = model(torch.from_numpy(all_questions[quest_number]).float().unsqueeze(0), torch.from_numpy(all_classes[class_number]).unsqueeze(0))
        output = torch.sigmoid(sim)
        print('*********')
        print(str(quest_number) + ' ' + str(class_number) )
        print(output)
# Out:
# *********
# 0 0
# tensor([[[0.9387]]], grad_fn=<SigmoidBackward>)
# *********
# 0 1
# tensor([[[0.6724]]], grad_fn=<SigmoidBackward>)
# *********
# 0 2
# tensor([[[0.6257]]], grad_fn=<SigmoidBackward>)
# *********
# 0 3
# tensor([[[0.6227]]], grad_fn=<SigmoidBackward>)
# *********
# 0 4
# tensor([[[0.0366]]], grad_fn=<SigmoidBackward>)
# *********
# 1 0
# tensor([[[0.7245]]], grad_fn=<SigmoidBackward>)
# *********
# 1 1
# tensor([[[0.2854]]], grad_fn=<SigmoidBackward>)
# *********
# 1 2
# tensor([[[0.1588]]], grad_fn=<SigmoidBackward>)
# *********
# 1 3
# tensor([[[0.2277]]], grad_fn=<SigmoidBackward>)
# *********
# 1 4
# tensor([[[0.0231]]], grad_fn=<SigmoidBackward>)
# *********
# 2 0
# tensor([[[0.5101]]], grad_fn=<SigmoidBackward>)
# *********
# 2 1
# tensor([[[0.5150]]], grad_fn=<SigmoidBackward>)
# *********
# 2 2
# tensor([[[0.6486]]], grad_fn=<SigmoidBackward>)
# *********
# 2 3
# tensor([[[0.5931]]], grad_fn=<SigmoidBackward>)
# *********
# 2 4
# tensor([[[0.0240]]], grad_fn=<SigmoidBackward>)
# *********
# 3 0
# tensor([[[0.7005]]], grad_fn=<SigmoidBackward>)
# *********
# 3 1
# tensor([[[0.4851]]], grad_fn=<SigmoidBackward>)
# *********
# 3 2
# tensor([[[0.3424]]], grad_fn=<SigmoidBackward>)
# *********
# 3 3
# tensor([[[0.4404]]], grad_fn=<SigmoidBackward>)
# *********
# 3 4
# tensor([[[0.0622]]], grad_fn=<SigmoidBackward>)
# *********
# 4 0
# tensor([[[0.1521]]], grad_fn=<SigmoidBackward>)
# *********
# 4 1
# tensor([[[0.2391]]], grad_fn=<SigmoidBackward>)
# *********
# 4 2
# tensor([[[0.9993]]], grad_fn=<SigmoidBackward>)
# *********
# 4 3
# tensor([[[0.9964]]], grad_fn=<SigmoidBackward>)
# *********
# 4 4
# tensor([[[0.0215]]], grad_fn=<SigmoidBackward>)
# *********
# 5 0
# tensor([[[0.0075]]], grad_fn=<SigmoidBackward>)
# *********
# 5 1
# tensor([[[0.0455]]], grad_fn=<SigmoidBackward>)
# *********
# 5 2
# tensor([[[0.9025]]], grad_fn=<SigmoidBackward>)
# *********
# 5 3
# tensor([[[0.8714]]], grad_fn=<SigmoidBackward>)
# *********
# 5 4
# tensor([[[0.0103]]], grad_fn=<SigmoidBackward>)
# *********
# 6 0
# tensor([[[0.0678]]], grad_fn=<SigmoidBackward>)
# *********
# 6 1
# tensor([[[0.2490]]], grad_fn=<SigmoidBackward>)
# *********
# 6 2
# tensor([[[0.7783]]], grad_fn=<SigmoidBackward>)
# *********
# 6 3
# tensor([[[0.8289]]], grad_fn=<SigmoidBackward>)
# *********
# 6 4
# tensor([[[0.0251]]], grad_fn=<SigmoidBackward>)
# *********
# 7 0
# tensor([[[0.2767]]], grad_fn=<SigmoidBackward>)
# *********
# 7 1
# tensor([[[0.3971]]], grad_fn=<SigmoidBackward>)
# *********
# 7 2
# tensor([[[0.9971]]], grad_fn=<SigmoidBackward>)
# *********
# 7 3
# tensor([[[0.9954]]], grad_fn=<SigmoidBackward>)
# *********
# 7 4
# tensor([[[0.0765]]], grad_fn=<SigmoidBackward>)
# *********
# 8 0
# tensor([[[0.1160]]], grad_fn=<SigmoidBackward>)
# *********
# 8 1
# tensor([[[0.0404]]], grad_fn=<SigmoidBackward>)
# *********
# 8 2
# tensor([[[0.7079]]], grad_fn=<SigmoidBackward>)
# *********
# 8 3
# tensor([[[0.6947]]], grad_fn=<SigmoidBackward>)
# *********
# 8 4
# tensor([[[0.4198]]], grad_fn=<SigmoidBackward>)
# *********
# 9 0
# tensor([[[0.9617]]], grad_fn=<SigmoidBackward>)
# *********
# 9 1
# tensor([[[0.7382]]], grad_fn=<SigmoidBackward>)
# *********
# 9 2
# tensor([[[0.9893]]], grad_fn=<SigmoidBackward>)
# *********
# 9 3
# tensor([[[0.9822]]], grad_fn=<SigmoidBackward>)
# *********
# 9 4
# tensor([[[0.3689]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# ### Construct "dictionary" associating topic labels, URIs and their embeddings ('uri_topic_dict.pkl')

# %%
uri_topic_dict = []
k=0
for key in list(training.keys()):
    values = training[key]["labels"]
    embedding_labels = infersent.encode(values, tokenize=True)
    embedding_label_av = np.mean(embedding_labels, axis=0)
    uri_topic_dict.append((k, key, values, embedding_label_av))
    k+=1
    
for key in list(test_labels.keys()):
    curr_labels = []
    for key1 in ['label', 'synonyms']:
        if isinstance(test_labels[key][key1], list):
            curr_labels += test_labels[key][key1]
        else:
            curr_labels += [test_labels[key][key1]]
    embedding_labels = infersent.encode(curr_labels, tokenize=True)
    embedding_label_av = np.mean(embedding_labels, axis=0)
    uri_topic_dict.append((k, key, curr_labels, embedding_label_av))
    k+=1

# %%
uri_topic_dict
# Out:
# [(0,
#   'http://www.wikidata.org/entity/P101',
#   ['field of study',
#    'fields',
#    'discipline',
#    'subject',
#    'area',
#    'specialism',
#    'domain',
#    'academic discipline',
#    'scientific discipline',
#    'academic subject',
#    'academic area',
#    'scientific area',
#    'FOW',
#    'field of work'],
#   array([ 0.00746889, -0.09179498,  0.00967923, ..., -0.03022508,
#          -0.05071909, -0.02850063], dtype=float32)),
#  (1,
#   'http://www.wikidata.org/entity/P1029',
#   ['crew member'],
#   array([ 0.00746889, -0.09595255, -0.02173634, ..., -0.01069365,
#          -0.05936687, -0.06587837], dtype=float32)),
#  (2,
#   'http://www.wikidata.org/entity/P1040',
#   ['editor', 'edited by', 'film editor'],
#   array([ 0.00746889, -0.09455415,  0.01290073, ..., -0.04508448,
#           0.04699417, -0.04150699], dtype=float32)),
#  (3,
#   'http://www.wikidata.org/entity/P105',
#   ['taxonomic rank', 'rank', 'type of taxon', 'taxon rank'],
#   array([ 0.00746889, -0.12191994,  0.05286136, ..., -0.02282107,
#          -0.02680972, -0.0277157 ], dtype=float32)),
#  (4,
#   'http://www.wikidata.org/entity/P106',
#   ['profession', 'job', 'work', 'career', 'employment', 'craft', 'occupation'],
#   array([ 0.00746889, -0.09369477,  0.00406455, ..., -0.02342394,
#          -0.05456912, -0.03570878], dtype=float32)),
#  (5,
#   'http://www.wikidata.org/entity/P1082',
#   ['inhabitants', 'human population', 'population'],
#   array([ 0.00746889, -0.11678901, -0.02201126, ..., -0.03053595,
#          -0.03637259, -0.0042838 ], dtype=float32)),
#  (6,
#   'http://www.wikidata.org/entity/P1083',
#   ['number of seats',
#    'seats',
#    'seating capacity',
#    'capacity',
#    'complement',
#    'crew',
#    'maximum capacity'],
#   array([ 0.00746889, -0.1090322 ,  0.03415957, ..., -0.06161226,
#          -0.05761572, -0.02552371], dtype=float32)),
#  (7,
#   'http://www.wikidata.org/entity/P1101',
#   ['number of floors', 'storeys', 'stories', 'floors above ground'],
#   array([ 0.00746889, -0.14113352,  0.03164708, ..., -0.03479409,
#           0.02442883, -0.00622076], dtype=float32)),
#  (8,
#   'http://www.wikidata.org/entity/P112',
#   ['is founded by',
#    'founded',
#    'co-founder',
#    'founders',
#    'founder',
#    'co-founded',
#    'was founded by',
#    'established by',
#    'founded by'],
#   array([ 0.00746889, -0.09020272,  0.01062813, ..., -0.00406058,
#           0.00302944, -0.03505066], dtype=float32)),
#  (9,
#   'http://www.wikidata.org/entity/P1128',
#   ['number of employees',
#    'workers',
#    'personnel',
#    'employee count',
#    'employees'],
#   array([ 0.00746889, -0.11115783, -0.02631274, ..., -0.02936626,
#          -0.05395389, -0.01726099], dtype=float32)),
#  (10,
#   'http://www.wikidata.org/entity/P113',
#   ['hub', 'hub airport', 'airline hub'],
#   array([ 0.00746889, -0.11049795,  0.06887881, ..., -0.02844986,
#           0.01697187, -0.01789737], dtype=float32)),
#  (11,
#   'http://www.wikidata.org/entity/P1142',
#   ['ideology', 'political ideology'],
#   array([ 0.00746889, -0.06506085, -0.06596207, ..., -0.01853116,
#          -0.00541435, -0.02311311], dtype=float32)),
#  (12,
#   'http://www.wikidata.org/entity/P115',
#   ['ground',
#    'home field',
#    'arena',
#    'home ground',
#    'stadium',
#    'ballpark',
#    'home water',
#    'home venue'],
#   array([ 0.00746889, -0.11702027, -0.00612974, ..., -0.05891509,
#          -0.02755768, -0.02618528], dtype=float32)),
#  (13,
#   'http://www.wikidata.org/entity/P1174',
#   ['visitors per year'],
#   array([ 0.00746889, -0.12081139,  0.08118473, ...,  0.00408778,
#          -0.05658534,  0.00345761], dtype=float32)),
#  (14,
#   'http://www.wikidata.org/entity/P119',
#   ['burial place',
#    'resting place',
#    'place of grave',
#    'buried in',
#    'grave at',
#    'location of burial',
#    'tomb',
#    'interment',
#    'place of interment',
#    'buried at',
#    'place of burial'],
#   array([ 0.00746889, -0.10639884, -0.00808805, ..., -0.04070521,
#          -0.03833726, -0.03714211], dtype=float32)),
#  (15,
#   'http://www.wikidata.org/entity/P122',
#   ['type of government',
#    'form of government',
#    'government',
#    'basic form of government'],
#   array([ 0.00746889, -0.08988998,  0.01207556, ..., -0.00359307,
#          -0.060884  , -0.00235663], dtype=float32)),
#  (16,
#   'http://www.wikidata.org/entity/P123',
#   ['book publisher',
#    'video game publisher',
#    'software publisher',
#    'publishing house',
#    'published by',
#    'board game publisher',
#    'publisher'],
#   array([ 0.00746889, -0.09961899,  0.01540328, ..., -0.01098731,
#           0.04296982, -0.02828511], dtype=float32)),
#  (17,
#   'http://www.wikidata.org/entity/P127',
#   ['is owned by',
#    'owner',
#    'belongs to',
#    'shareholder',
#    'stockholder',
#    'shareholders',
#    'stockholders',
#    'owners',
#    'provenance',
#    'owned by'],
#   array([ 0.00746889, -0.0232072 , -0.0124549 , ..., -0.01527017,
#          -0.02028242, -0.03585616], dtype=float32)),
#  (18,
#   'http://www.wikidata.org/entity/P1303',
#   ['plays', 'musical instrument', 'instrument'],
#   array([ 0.00746889, -0.0162352 ,  0.1047081 , ..., -0.0455931 ,
#          -0.06475541, -0.00867746], dtype=float32)),
#  (19,
#   'http://www.wikidata.org/entity/P1308',
#   ['incumbent', 'officeholder'],
#   array([ 0.00746889, -0.07011655, -0.01331416, ..., -0.03767011,
#          -0.04040495, -0.05860477], dtype=float32)),
#  (20,
#   'http://www.wikidata.org/entity/P131',
#   ['located in the administrative unit',
#    'located in administrative unit',
#    'is in administrative unit',
#    'is located in',
#    'is in the state of',
#    'is in the province of',
#    'is in the county of',
#    'is in the district of',
#    'is in the department of',
#    'is in the region of',
#    'is in the borough of',
#    'is in the city of',
#    'is in the town of',
#    'is in the village of',
#    'is in the municipality of',
#    'is in the territory of',
#    'is in the prefecture of',
#    'is in the voivodeship of',
#    'is in the Indian reservation of',
#    'is in the Indian reserve of',
#    'is in the ward of',
#    'is in the administrative region of',
#    'is in the settlement of',
#    'is in the local government area of',
#    'is in the rural city of',
#    'is in the shire of',
#    'happens in',
#    'is in the commune of',
#    'in administrative unit',
#    'in',
#    'is in the administrative unit',
#    'administrative territorial entity',
#    'city',
#    'town',
#    'state',
#    'Indian reservation',
#    'in the administrative unit',
#    'locality',
#    'is in the parish of',
#    'location (administrative territorial entity)',
#    'is in the principal area of',
#    'based in',
#    'located in the administrative territorial entity',
#    'located in the territorial entity',
#    'region',
#    'located in area'],
#   array([ 0.00746889, -0.10035761,  0.0107002 , ..., -0.01955368,
#          -0.03936182, -0.00059711], dtype=float32)),
#  (21,
#   'http://www.wikidata.org/entity/P1313',
#   ['office of head of government',
#    'position of head of government',
#    'position held by head of government',
#    'title of head of government',
#    'office held by head of government'],
#   array([ 0.00746889, -0.07614501,  0.0074209 , ..., -0.00359307,
#          -0.03278311, -0.00235663], dtype=float32)),
#  (22,
#   'http://www.wikidata.org/entity/P135',
#   ['school', 'trend', 'movement'],
#   array([ 0.00746889, -0.1318391 , -0.04368946, ..., -0.04859178,
#          -0.03640259, -0.03866735], dtype=float32)),
#  (23,
#   'http://www.wikidata.org/entity/P136',
#   ['music genre',
#    'film genre',
#    'artistic genre',
#    'literary genre',
#    'kind of music',
#    'type of film',
#    'genre of music',
#    'type of music',
#    'genre'],
#   array([ 0.00746889, -0.11491671,  0.12136432, ..., -0.04867068,
#          -0.00116275, -0.04549991], dtype=float32)),
#  (24,
#   'http://www.wikidata.org/entity/P1365',
#   ['forefather',
#    'previous job holder',
#    'replaced',
#    'preceded by',
#    'succeeds',
#    'after',
#    'predecessor',
#    'supersedes',
#    'continues from',
#    'replaces'],
#   array([ 0.00746889, -0.03690854,  0.00075284, ..., -0.04466995,
#          -0.03505586, -0.0316157 ], dtype=float32)),
#  (25,
#   'http://www.wikidata.org/entity/P137',
#   ['service operator',
#    'facility operator',
#    'operated by',
#    'managed by',
#    'administrator',
#    'item operator',
#    'user',
#    'operator'],
#   array([ 0.00746889, -0.06273175,  0.02421567, ..., -0.03576022,
#          -0.02512793, -0.02627853], dtype=float32)),
#  (26,
#   'http://www.wikidata.org/entity/P138',
#   ['eponym',
#    'named for',
#    'namesake',
#    'etymology',
#    'toponym',
#    'name after',
#    'named after'],
#   array([ 0.00746889, -0.10393412,  0.00954461, ..., -0.02959974,
#          -0.0168234 , -0.02161496], dtype=float32)),
#  (27,
#   'http://www.wikidata.org/entity/P140',
#   ['faith',
#    'religious affiliation',
#    'life stance',
#    'denomination',
#    'religion'],
#   array([ 0.00746889, -0.04945031,  0.02897425, ..., -0.00489116,
#          -0.01283371, -0.04476549], dtype=float32)),
#  (28,
#   'http://www.wikidata.org/entity/P1408',
#   ['city of license', 'community of license', 'licensed to broadcast to'],
#   array([ 0.00746889, -0.11682684,  0.09541557, ..., -0.0048597 ,
#           0.00229425, -0.01816681], dtype=float32)),
#  (29,
#   'http://www.wikidata.org/entity/P1412',
#   ['languages spoken',
#    'language spoken',
#    'language of expression',
#    'languages of expression',
#    'languages signed',
#    'language signed',
#    'language written',
#    'language read',
#    'language used',
#    'language',
#    'speaks language',
#    'writes language',
#    'signs language',
#    'uses language',
#    'wrote language',
#    'spoke language',
#    'used language',
#    'signed language',
#    'second language',
#    'languages spoken',
#    ' written',
#    ' or signed',
#    'language(s) spoken',
#    ' written or signed',
#    'languages spoken, written or signed'],
#   array([ 0.00746889, -0.10217965,  0.02561154, ...,  0.003572  ,
#          -0.00536312, -0.00718582], dtype=float32)),
#  (30,
#   'http://www.wikidata.org/entity/P1416',
#   ['affiliated with', 'affiliation'],
#   array([ 0.00746889, -0.10511345,  0.05201583, ...,  0.00457533,
#          -0.00929508, -0.04822817], dtype=float32)),
#  (31,
#   'http://www.wikidata.org/entity/P1431',
#   ['executive producer'],
#   array([ 0.00746889, -0.04633453, -0.0374175 , ...,  0.02054253,
#           0.0094157 , -0.01533123], dtype=float32)),
#  (32,
#   'http://www.wikidata.org/entity/P144',
#   ['fork of',
#    'derived from',
#    'extended from',
#    'copy of',
#    'adapted from',
#    'based upon',
#    'theme',
#    'themed after',
#    'adaptation of',
#    'remake of',
#    'based on'],
#   array([ 0.00746889, -0.10345223,  0.01574354, ..., -0.03578654,
#          -0.02553498, -0.02091421], dtype=float32)),
#  (33,
#   'http://www.wikidata.org/entity/P1451',
#   ['slogan', 'mission statement', 'mission', 'tagline', 'motto text'],
#   array([ 0.00746889, -0.10449938,  0.0244074 , ..., -0.01660076,
#          -0.01616817, -0.02095892], dtype=float32)),
#  (34,
#   'http://www.wikidata.org/entity/P1477',
#   ['maiden name',
#    'born as',
#    'bn',
#    'bname',
#    'birth name (monolingual text)',
#    'name',
#    'birthname',
#    'name at birth',
#    'full name at birth',
#    'nee',
#    'real name',
#    'birth name'],
#   array([ 0.00746889, -0.02811707,  0.01307602, ..., -0.00902223,
#          -0.01288703, -0.03169743], dtype=float32)),
#  (35,
#   'http://www.wikidata.org/entity/P149',
#   ['style of architecture', 'architecture', 'architectural style'],
#   array([ 0.00746889, -0.09993166,  0.10164318, ..., -0.01649266,
#          -0.00918801, -0.00079385], dtype=float32)),
#  (36,
#   'http://www.wikidata.org/entity/P150',
#   ['contains',
#    'divides into',
#    'divided into',
#    'has towns',
#    'has shires',
#    'has cities',
#    'has rural cities',
#    'has municipalities',
#    'has wards',
#    'has local government areas',
#    'has districts',
#    'has boroughs',
#    'subdivided into',
#    'has counties',
#    'has administrative divisions',
#    'has arrondissements',
#    'has villages',
#    'has regions',
#    'contains administrative territorial entity'],
#   array([ 0.00746889, -0.10830549, -0.02130332, ...,  0.01039621,
#          -0.0334546 , -0.0105994 ], dtype=float32)),
#  (37,
#   'http://www.wikidata.org/entity/P155',
#   ['succeeds to',
#    'previous is',
#    'before was',
#    'predecessor',
#    'preceded by',
#    'prequel is',
#    'sequel of',
#    'split from',
#    'followed',
#    'comes after',
#    'follows'],
#   array([ 0.00746889, -0.08202343, -0.04085987, ..., -0.04779879,
#          -0.03197414, -0.01843197], dtype=float32)),
#  (38,
#   'http://www.wikidata.org/entity/P156',
#   ['succeded by',
#    'next is',
#    'precedes',
#    'sequel is',
#    'prequel of',
#    'successor',
#    'preceeds',
#    'followed by'],
#   array([ 0.00746889, -0.07077838, -0.01557669, ..., -0.05068898,
#          -0.02579623, -0.01779506], dtype=float32)),
#  (39,
#   'http://www.wikidata.org/entity/P159',
#   ['head office location',
#    'HQ',
#    'garrison',
#    'admin HQ',
#    'seat',
#    'principle office',
#    'headquarters',
#    'head quarters',
#    'HQ location',
#    'headquarters location'],
#   array([ 0.00746889, -0.09187677, -0.00761565, ..., -0.02767542,
#          -0.0261067 , -0.01383967], dtype=float32)),
#  (40,
#   'http://www.wikidata.org/entity/P161',
#   ['starring',
#    'film starring',
#    'actor',
#    'actress',
#    'contestant',
#    'cast member'],
#   array([ 0.00746889, -0.09199479, -0.01167581, ..., -0.07401066,
#          -0.03245008, -0.01025101], dtype=float32)),
#  (41,
#   'http://www.wikidata.org/entity/P1619',
#   ['time of official opening',
#    'opening date',
#    'opened',
#    'date opened',
#    'officially opened on',
#    'inaugurated',
#    'launch date',
#    'introduced',
#    'introduction',
#    'official opening',
#    'date of official opening'],
#   array([ 0.00746889, -0.08507169, -0.00433902, ..., -0.04797852,
#          -0.0475261 , -0.00717444], dtype=float32)),
#  (42,
#   'http://www.wikidata.org/entity/P162',
#   ['record producer', 'film producer', 'producer'],
#   array([ 0.00746889, -0.09567472, -0.06039725, ..., -0.0102793 ,
#           0.0034788 , -0.01594857], dtype=float32)),
#  (43,
#   'http://www.wikidata.org/entity/P17',
#   ['sovereign state', 'state', 'land', 'country'],
#   array([ 0.00746889, -0.08347838,  0.00314358, ..., -0.01419878,
#          -0.0448012 , -0.01749342], dtype=float32)),
#  (44,
#   'http://www.wikidata.org/entity/P170',
#   ['artist (non-musical)',
#    'created by',
#    'painter',
#    'sculptor',
#    'creators',
#    'painters',
#    'sculptors',
#    'made by',
#    'creator'],
#   array([ 0.00746889, -0.060755  ,  0.07405219, ..., -0.04457568,
#          -0.01844842, -0.00682527], dtype=float32)),
#  (45,
#   'http://www.wikidata.org/entity/P171',
#   ['taxon parent', 'higher taxon', 'parent taxon'],
#   array([ 0.00746889, -0.06128475, -0.01963148, ..., -0.08235862,
#          -0.06192419, -0.02307939], dtype=float32)),
#  (46,
#   'http://www.wikidata.org/entity/P172',
#   ['ethnicity', 'nationality', 'culture', 'peoples', 'ethnic group'],
#   array([ 0.00746889, -0.05650676,  0.02059677, ..., -0.00867013,
#           0.01156505, -0.03743229], dtype=float32)),
#  (47,
#   'http://www.wikidata.org/entity/P175',
#   ['musical artist',
#    'artist',
#    'musician',
#    'played by',
#    'portrayed by',
#    'performer'],
#   array([ 0.00746889, -0.0776636 ,  0.07201124, ..., -0.05820831,
#          -0.01405012, -0.0246606 ], dtype=float32)),
#  (48,
#   'http://www.wikidata.org/entity/P176',
#   ['manufactured by',
#    'maker',
#    'mfr',
#    'built by',
#    'builder',
#    'made by',
#    'producer (of product)',
#    'product of',
#    'manufacturer'],
#   array([ 0.00746889, -0.05877689,  0.00449553, ..., -0.01444526,
#          -0.02634326,  0.00618618], dtype=float32)),
#  (49,
#   'http://www.wikidata.org/entity/P177',
#   ['bridge over', 'tunnel under', 'over', 'under', 'through', 'crosses'],
#   array([ 0.00746889, -0.121871  ,  0.01533099, ..., -0.04790653,
#          -0.02484477, -0.01229053], dtype=float32)),
#  (50,
#   'http://www.wikidata.org/entity/P178',
#   ['developed by', 'developer'],
#   array([ 0.00746889, -0.07690419,  0.03108859, ..., -0.02016054,
#           0.00286667, -0.02188784], dtype=float32)),
#  (51,
#   'http://www.wikidata.org/entity/P179',
#   ['part of series', 'part of the series'],
#   array([ 7.4688899e-03, -1.0456637e-01, -1.1113700e-03, ...,
#          -3.5516497e-02, -3.5961188e-02, -9.5864641e-05], dtype=float32)),
#  (52,
#   'http://www.wikidata.org/entity/P184',
#   ['advisor',
#    'doctoral supervisor',
#    'supervisor',
#    'PhD advisor',
#    'doctoral advisor'],
#   array([ 0.00746889, -0.11381163,  0.03966039, ..., -0.01805003,
#          -0.01831937, -0.03414972], dtype=float32)),
#  (53,
#   'http://www.wikidata.org/entity/P189',
#   ['findspot',
#    'location of discovered object',
#    'discovery place',
#    'place of discovery',
#    'discovered at:',
#    'location of discovery'],
#   array([ 0.00746889, -0.09467888,  0.03925101, ..., -0.04991708,
#          -0.04148854, -0.01669712], dtype=float32)),
#  (54,
#   'http://www.wikidata.org/entity/P19',
#   ['birthplace',
#    'born in',
#    'POB',
#    'birth place',
#    'location born',
#    'born at',
#    'birth location',
#    'location of birth',
#    'birth city',
#    'place of birth'],
#   array([ 0.00746889, -0.01930997,  0.02339626, ..., -0.02404313,
#          -0.02657312, -0.03164493], dtype=float32)),
#  (55,
#   'http://www.wikidata.org/entity/P196',
#   ['asteroid group', 'minor planet group'],
#   array([ 0.00746889, -0.08610073,  0.01615429, ..., -0.06988347,
#          -0.0342306 ,  0.00387429], dtype=float32)),
#  (56,
#   'http://www.wikidata.org/entity/P20',
#   ['deathplace',
#    'died in',
#    'death place',
#    'POD',
#    'location of death',
#    'death location',
#    'place of death'],
#   array([ 0.00746889, -0.09001659, -0.0378204 , ..., -0.06287862,
#          -0.04490203, -0.03310474], dtype=float32)),
#  (57,
#   'http://www.wikidata.org/entity/P201',
#   ['outflows', 'outflow', 'lake outflow'],
#   array([ 0.00746889, -0.1184074 , -0.01794477, ..., -0.08980736,
#          -0.06475542,  0.03361703], dtype=float32)),
#  (58,
#   'http://www.wikidata.org/entity/P2043',
#   ['distance', 'dimension', 'size', 'long', 'length'],
#   array([ 0.00746889, -0.09954387,  0.00480343, ..., -0.06210579,
#          -0.02833203, -0.01301314], dtype=float32)),
#  (59,
#   'http://www.wikidata.org/entity/P2046',
#   ['surface area', 'acreage', 'surface', 'size', 'total area', 'area'],
#   array([ 0.00746889, -0.11344489, -0.02013192, ..., -0.05870606,
#          -0.04896717, -0.01971629], dtype=float32)),
#  (60,
#   'http://www.wikidata.org/entity/P2048',
#   ['depth over terrain', 'size', 'height'],
#   array([ 0.00746889, -0.09773331,  0.0291578 , ..., -0.01622953,
#          -0.02557292,  0.01033014], dtype=float32)),
#  (61,
#   'http://www.wikidata.org/entity/P21',
#   ['gender identity',
#    'gender expression',
#    'gender',
#    'biological sex',
#    'man',
#    'woman',
#    'male',
#    'female',
#    'intersex',
#    'sex',
#    'sex or gender'],
#   array([ 0.00746889, -0.0107792 , -0.02853255, ..., -0.06071726,
#          -0.01718169, -0.04083589], dtype=float32)),
#  (62,
#   'http://www.wikidata.org/entity/P2130',
#   ['unit cost', 'cost'],
#   array([ 0.00746889, -0.09465875, -0.05220351, ..., -0.01860581,
#          -0.03456102, -0.01050231], dtype=float32)),
#  (63,
#   'http://www.wikidata.org/entity/P2196',
#   ['number of students',
#    'student count',
#    'count of students',
#    'enrollment',
#    'students count'],
#   array([ 0.00746889, -0.12424877,  0.00655648, ..., -0.03533993,
#          -0.05543658, -0.00916746], dtype=float32)),
#  (64,
#   'http://www.wikidata.org/entity/P22',
#   ['dad',
#    'daddy',
#    'has father',
#    'parent',
#    'is son of',
#    'is daughter of',
#    'is child of',
#    'son of',
#    'daughter of',
#    'child of',
#    'father'],
#   array([ 0.00746889,  0.04048086, -0.0109618 , ..., -0.03308188,
#          -0.04664158, -0.03136373], dtype=float32)),
#  (65,
#   'http://www.wikidata.org/entity/P25',
#   ['mum',
#    'mom',
#    'mam',
#    'has mother',
#    'parent',
#    'is son of',
#    'is daughter of',
#    'is child of',
#    'son of',
#    'daughter of',
#    'child of',
#    'mother'],
#   array([ 0.00746889, -0.03346855, -0.01876701, ..., -0.03925255,
#          -0.04086696, -0.02963777], dtype=float32)),
#  (66,
#   'http://www.wikidata.org/entity/P26',
#   ['husband',
#    'wife',
#    'married to',
#    'consort',
#    'partner',
#    'marry',
#    'marriage partner',
#    'married',
#    'wedded to',
#    'wed',
#    'life partner',
#    'spouse'],
#   array([ 0.00746889, -0.01543902,  0.06391454, ..., -0.05936284,
#          -0.03390509, -0.03482908], dtype=float32)),
#  (67,
#   'http://www.wikidata.org/entity/P264',
#   ['label', 'record label'],
#   array([ 0.00746889, -0.10601339, -0.06921252, ..., -0.02622161,
#          -0.01574429, -0.02864224], dtype=float32)),
#  (68,
#   'http://www.wikidata.org/entity/P27',
#   ['citizenship',
#    'nationality',
#    'citizen of',
#    'national of',
#    'subject of (country)',
#    'country of citizenship'],
#   array([ 0.00746889, -0.06430121,  0.01530017, ...,  0.01004987,
#          -0.01810502, -0.02732919], dtype=float32)),
#  (69,
#   'http://www.wikidata.org/entity/P272',
#   ['film studio',
#    'studio',
#    'motion picture studio',
#    'movie studio',
#    'production house',
#    'theatre company',
#    'theater company',
#    'theatrical troupe',
#    'ballet company',
#    'broadcasting company',
#    'production company'],
#   array([ 0.00746889, -0.1090058 ,  0.02030014, ..., -0.04134914,
#          -0.01161814, -0.01356712], dtype=float32)),
#  (70,
#   'http://www.wikidata.org/entity/P275',
#   ['licence', 'content license', 'content licence', 'license'],
#   array([ 0.00746889, -0.10471985,  0.06848736, ..., -0.01159918,
#          -0.01948962, -0.05370393], dtype=float32)),
#  (71,
#   'http://www.wikidata.org/entity/P276',
#   ['moveable object location',
#    'located in',
#    'event location',
#    'venue',
#    'is in',
#    'location of item',
#    'place held',
#    'based in',
#    'neighborhood',
#    'region',
#    'location'],
#   array([ 0.00746889, -0.10612488,  0.00411006, ..., -0.06185686,
#          -0.03420629, -0.02278197], dtype=float32)),
#  (72,
#   'http://www.wikidata.org/entity/P279',
#   ['rdfs:subClassOf',
#    'hyponym of',
#    'has superclass',
#    'is also a',
#    'subtype of',
#    'is a subtype of',
#    'subcategory of',
#    'is a category of',
#    'is thereby also a',
#    'is necessarily also a',
#    'whose instances are among',
#    'whose instances are those of',
#    'subclass of'],
#   array([ 0.00746889, -0.09489362, -0.00103573, ..., -0.02631658,
#          -0.04437238, -0.01332397], dtype=float32)),
#  (73,
#   'http://www.wikidata.org/entity/P286',
#   ['manager',
#    'club manager',
#    'senior coach',
#    'team manager',
#    'coach',
#    'coached by',
#    'head coach'],
#   array([ 0.00746889, -0.12295233,  0.00291875, ...,  0.01217922,
#          -0.03073566, -0.04323285], dtype=float32)),
#  (74,
#   'http://www.wikidata.org/entity/P287',
#   ['has designer', 'designer', 'designed by'],
#   array([ 0.00746889, -0.07828129,  0.03180908, ..., -0.03756708,
#           0.0018231 , -0.01830566], dtype=float32)),
#  (75,
#   'http://www.wikidata.org/entity/P289',
#   ['ship class',
#    'submarine class',
#    'spacecraft class',
#    'class of vessel',
#    'vessel class'],
#   array([ 0.00746889, -0.08817574, -0.05495982, ..., -0.04128509,
#          -0.04842551, -0.01853842], dtype=float32)),
#  (76,
#   'http://www.wikidata.org/entity/P31',
#   ['is a',
#    'is an',
#    'has class',
#    'has type',
#    'is a particular',
#    'is a specific',
#    'is an individual',
#    'is a unique',
#    'is an example of',
#    'member of',
#    'unique individual of',
#    'distinct member of',
#    'non-type member of',
#    'unsubclassable example of',
#    'uninstantiable instance of',
#    'unsubclassifiable member of',
#    'not a type but is instance of',
#    'unsubtypable particular',
#    'unitary element of class',
#    'distinct element of',
#    'distinct individual member of',
#    'occurrence of',
#    'rdf:type',
#    'type',
#    'instance of',
#    'is a',
#    'is an',
#    'has class',
#    'has type',
#    'is a particular',
#    'is a specific',
#    'is an individual',
#    'is a unique',
#    'is an example of',
#    'member of',
#    'unique individual of',
#    'distinct member of',
#    'non-type member of',
#    'unsubclassable example of',
#    'uninstantiable instance of',
#    'unsubclassifiable member of',
#    'not a type but is instance of',
#    'unsubtypable particular',
#    'unitary element of class',
#    'distinct element of',
#    'distinct individual member of',
#    'occurrence of',
#    'rdf:type',
#    'type',
#    'instance of'],
#   array([ 0.00746889, -0.10151681,  0.00212692, ..., -0.02448319,
#          -0.04749737, -0.01547655], dtype=float32)),
#  (77,
#   'http://www.wikidata.org/entity/P344',
#   ['cinematographer', 'DOP', 'director of photography'],
#   array([ 0.00746889, -0.01745754,  0.07742625, ..., -0.03224602,
#          -0.02825398, -0.03121058], dtype=float32)),
#  (78,
#   'http://www.wikidata.org/entity/P36',
#   ['capital city',
#    'capital town',
#    'chef-lieu',
#    'principal place',
#    'county seat',
#    'administrative centre',
#    'administrative headquarters',
#    'capital'],
#   array([ 0.00746889, -0.12022485, -0.01473773, ..., -0.03171764,
#          -0.04151522,  0.00369991], dtype=float32)),
#  (79,
#   'http://www.wikidata.org/entity/P361',
#   ['meronym of',
#    'section of',
#    'system of',
#    'subsystem of',
#    'subassembly of',
#    'merged into',
#    'contained within',
#    'assembly of',
#    'part of-property',
#    'merged with',
#    'component of',
#    'in',
#    'within',
#    'part of'],
#   array([ 0.00746889, -0.10833788,  0.010845  , ..., -0.04871992,
#          -0.04551169, -0.00840333], dtype=float32)),
#  (80,
#   'http://www.wikidata.org/entity/P364',
#   ['original language',
#    'language of the original work',
#    'created on language',
#    'original language of film or TV show'],
#   array([ 0.00746889, -0.04833895,  0.05356934, ..., -0.0281768 ,
#           0.00561129, -0.00910143], dtype=float32)),
#  (81,
#   'http://www.wikidata.org/entity/P376',
#   ['planet', 'astronomical body (location)', 'on astronomical body'],
#   array([ 0.00746889, -0.05372881,  0.01455377, ..., -0.05911385,
#          -0.02554132,  0.00890275], dtype=float32)),
#  (82,
#   'http://www.wikidata.org/entity/P397',
#   ['parent body',
#    'orbits',
#    'star',
#    'planetary system',
#    'parent astronomical body'],
#   array([ 0.00746889, -0.06552197,  0.01394539, ..., -0.06235822,
#          -0.04485999,  0.00201396], dtype=float32)),
#  (83,
#   'http://www.wikidata.org/entity/P398',
#   ['child body',
#    'satellite',
#    'orbited by',
#    'has planet',
#    'has moon',
#    'child astronomical body'],
#   array([ 0.00746889, -0.08117469,  0.01556168, ..., -0.03923402,
#          -0.0329527 ,  0.00505446], dtype=float32)),
#  (84,
#   'http://www.wikidata.org/entity/P40',
#   ['son',
#    'daughter',
#    'kid',
#    'has child',
#    'children',
#    'sons',
#    'daughters',
#    'kids',
#    'has children',
#    'has son',
#    'has sons',
#    'has daughter',
#    'has daughters',
#    'has kid',
#    'has kids',
#    'parent of',
#    'child'],
#   array([ 0.00746889, -0.01930528, -0.02803884, ..., -0.01705814,
#          -0.04769382, -0.03648052], dtype=float32)),
#  (85,
#   'http://www.wikidata.org/entity/P403',
#   ['watercourse outflow',
#    'watercourse drain',
#    'tributary of',
#    'outflow',
#    'drain',
#    'river mouth',
#    'outlet',
#    'confluences',
#    'watercourse ends in',
#    'mouth of the watercourse'],
#   array([ 0.00746889, -0.10943554,  0.01659429, ..., -0.06757563,
#          -0.04378536, -0.00860567], dtype=float32)),
#  (86,
#   'http://www.wikidata.org/entity/P404',
#   ['mode', 'gameplay', 'game mode'],
#   array([ 0.00746889, -0.09820456, -0.04176806, ..., -0.06294233,
#          -0.05383183, -0.04310402], dtype=float32)),
#  (87,
#   'http://www.wikidata.org/entity/P407',
#   ['language of the name',
#    'language of name',
#    'named in language',
#    'broadcasting language',
#    'audio language',
#    'available in',
#    'language of work',
#    'language of the reference',
#    'language of work or name'],
#   array([ 0.00746889, -0.09457623,  0.0291924 , ..., -0.02507537,
#          -0.01385907, -0.0176533 ], dtype=float32)),
#  (88,
#   'http://www.wikidata.org/entity/P413',
#   ['player position',
#    'fielding position',
#    'specialism',
#    'position (on team)',
#    'speciality',
#    'position played on team / speciality'],
#   array([ 0.00746889, -0.08159697,  0.03214568, ..., -0.01133625,
#          -0.05125558, -0.03418026], dtype=float32)),
#  (89,
#   'http://www.wikidata.org/entity/P421',
#   ['timezone', 'tz', 'time zone', 'time', 'located in time zone'],
#   array([ 0.00746889, -0.06004321, -0.05043457, ...,  0.02023556,
#          -0.04693506, -0.00919832], dtype=float32)),
#  (90,
#   'http://www.wikidata.org/entity/P452',
#   ['field of action',
#    'field of exercise',
#    'sector',
#    'branch',
#    'economic branch',
#    'industry'],
#   array([ 0.00746889, -0.11876743,  0.00349247, ..., -0.04196915,
#          -0.04975629, -0.03026739], dtype=float32)),
#  (91,
#   'http://www.wikidata.org/entity/P466',
#   ['occupied by', 'tenant', 'inhabitant', 'inhabited by', 'occupant'],
#   array([ 0.00746889, -0.09014051, -0.01580956, ..., -0.06179535,
#          -0.01865068, -0.03537717], dtype=float32)),
#  (92,
#   'http://www.wikidata.org/entity/P488',
#   ['chairman',
#    'chairwoman',
#    'leader',
#    'headed by',
#    'president',
#    'chairperson'],
#   array([ 0.00746889, -0.09487313, -0.00211038, ..., -0.03418916,
#          -0.03051691, -0.03551855], dtype=float32)),
#  (93,
#   'http://www.wikidata.org/entity/P495',
#   ['place of origin',
#    'comes from',
#    'origin (country)',
#    'originates',
#    'CoO',
#    'country of origin'],
#   array([ 0.00746889, -0.0672641 ,  0.00579072, ..., -0.00508729,
#          -0.02668478, -0.01347279], dtype=float32)),
#  (94,
#   'http://www.wikidata.org/entity/P50',
#   ['written by',
#    'writer',
#    'writers',
#    'authors',
#    'author(s)',
#    'writer(s)',
#    'author'],
#   array([ 0.00746889, -0.08519266, -0.00561788, ..., -0.00898431,
#           0.00924559, -0.0180424 ], dtype=float32)),
#  (95,
#   'http://www.wikidata.org/entity/P509',
#   ['death cause',
#    'die from',
#    'murder method',
#    'method of murder',
#    'cause of death'],
#   array([ 0.00746889, -0.08087448, -0.00289316, ..., -0.03800194,
#          -0.02910612, -0.02600964], dtype=float32)),
#  (96,
#   'http://www.wikidata.org/entity/P53',
#   ['royal house', 'dynasty', 'house', 'noble family', 'family'],
#   array([ 0.00746889, -0.08968775,  0.05547171, ..., -0.02782292,
#          -0.0267676 , -0.05228692], dtype=float32)),
#  (97,
#   'http://www.wikidata.org/entity/P569',
#   ['born on',
#    'birth date',
#    'birthdate',
#    'birth year',
#    'year of birth',
#    'birthyear',
#    'DOB',
#    'birthday',
#    'date of birth'],
#   array([ 0.00746889, -0.00334357,  0.02261555, ..., -0.00888429,
#          -0.03622377, -0.01718537], dtype=float32)),
#  (98,
#   'http://www.wikidata.org/entity/P57',
#   ['directed by', 'film director', 'movie director', 'director'],
#   array([ 0.00746889, -0.0775247 , -0.01932754, ..., -0.03635337,
#          -0.0026705 , -0.02463046], dtype=float32)),
#  (99,
#   'http://www.wikidata.org/entity/P570',
#   ['date of the end',
#    'death date',
#    'died on',
#    'DOD',
#    'year of death',
#    'dead',
#    'deathdate',
#    'death',
#    'date of death'],
#   array([ 0.00746889, -0.08889773, -0.04126688, ..., -0.05447251,
#          -0.05123369, -0.01458549], dtype=float32)),
#  (100,
#   'http://www.wikidata.org/entity/P571',
#   ['date founded',
#    'date created',
#    'incorporated',
#    'foundation',
#    'founded',
#    'created',
#    'date of foundation',
#    'date of creation',
#    'established',
#    'establishment date',
#    'foundation date',
#    'creation date',
#    'incorporation date',
#    'date incorporated',
#    'date of incorporation',
#    'date of establishment',
#    'founding date',
#    'date of founding',
#    'date formed',
#    'formation date',
#    'formed on date',
#    'founded on date',
#    'incorporated on date',
#    'established on date',
#    'created on date',
#    'commencement date',
#    'date commenced',
#    'commenced on date',
#    'date of commencement',
#    'foundation/creation date',
#    'time of foundation or creation',
#    'date of foundation or creation',
#    'written on date',
#    'time of inception',
#    'year founded',
#    'year created',
#    'year incorporated',
#    'year written',
#    'year commenced',
#    'year established',
#    'date constructed',
#    'construction date',
#    'constructed',
#    'inititated',
#    'formation',
#    'dedication date',
#    'formed in',
#    'formed at',
#    'inaugurated',
#    'launch date',
#    'introduced',
#    'introduction',
#    'start date',
#    'completed',
#    'first issue',
#    'inception'],
#   array([ 0.00746889, -0.08429937,  0.01679092, ..., -0.03570899,
#          -0.04545629,  0.00372993], dtype=float32)),
#  (101,
#   'http://www.wikidata.org/entity/P58',
#   ['scriptwriter',
#    'screenplay by',
#    'teleplay by',
#    'writer (of screenplays)',
#    'film script by',
#    'screenwriter'],
#   array([ 0.00746889, -0.07585476, -0.02054208, ..., -0.06021911,
#           0.03894403, -0.02066674], dtype=float32)),
#  (102,
#   'http://www.wikidata.org/entity/P59',
#   ['part of constellation', 'constellation'],
#   array([ 0.00746889, -0.12448856,  0.04086464, ..., -0.05161938,
#          -0.05475156,  0.0334425 ], dtype=float32)),
#  (103,
#   'http://www.wikidata.org/entity/P6',
#   ['mayor',
#    'prime minister',
#    'premier',
#    'first minister',
#    'head of national government',
#    'chancellor',
#    'governor',
#    'government headed by',
#    'executive power headed by',
#    'president',
#    'head of government'],
#   array([ 0.00746889, -0.07440884,  0.00678919, ...,  0.00227248,
#          -0.01890069, -0.01602917], dtype=float32)),
#  (104,
#   'http://www.wikidata.org/entity/P607',
#   ['war',
#    'battle',
#    'participated in conflict',
#    'participant in conflict',
#    'in conflict',
#    'in action',
#    'theater (military)',
#    'theatre (military)',
#    'conflict'],
#   array([ 0.00746889, -0.08776493, -0.0140864 , ..., -0.04892388,
#          -0.04365614, -0.00997769], dtype=float32)),
#  (105,
#   'http://www.wikidata.org/entity/P61',
#   ['inventor',
#    'discovered by',
#    'invented by',
#    'discoverer',
#    'coined by',
#    'first described by',
#    'inventor or discoverer',
#    'invented or discovered by',
#    'discovered or invented by',
#    'developer',
#    'developed by',
#    'discoverer or inventor'],
#   array([ 0.00746889, -0.02059271,  0.04111049, ..., -0.01535775,
#           0.00664134, -0.01525358], dtype=float32)),
#  (106,
#   'http://www.wikidata.org/entity/P641',
#   ['sports', 'sport played', 'sport'],
#   array([ 0.00746889, -0.11141273,  0.0349226 , ..., -0.03551095,
#          -0.06395694, -0.05034419], dtype=float32)),
#  (107,
#   'http://www.wikidata.org/entity/P65',
#   ['discovery site', 'site of astronomical discovery'],
#   array([ 0.00746889, -0.06918618,  0.08389997, ..., -0.04532529,
#          -0.04476157,  0.0233233 ], dtype=float32)),
#  (108,
#   'http://www.wikidata.org/entity/P676',
#   ['lyricist',
#    'lyracist',
#    'words by',
#    'writer (of song lyrics)',
#    'author',
#    'lyrics by'],
#   array([ 0.00746889, -0.09283764,  0.02717627, ..., -0.0484614 ,
#           0.01360821, -0.02913518], dtype=float32)),
#  (109,
#   'http://www.wikidata.org/entity/P69',
#   ['education',
#    'alumni of',
#    'alumnus of',
#    'alumna of',
#    'college attended',
#    'university attended',
#    'school attended',
#    'studied at',
#    'alma mater',
#    'graduate of',
#    'graduated from',
#    'faculty',
#    'educated at'],
#   array([ 0.00746889, -0.11812532,  0.03232218, ...,  0.0037202 ,
#          -0.02412255, -0.03048944], dtype=float32)),
#  (110,
#   'http://www.wikidata.org/entity/P710',
#   ['participants',
#    'attendee',
#    'player',
#    'competitor',
#    'candidate',
#    'party',
#    'event participant',
#    'agent',
#    'belligerents',
#    'between',
#    'victim',
#    'perpetrator',
#    'suspect',
#    'accused',
#    'participant'],
#   array([ 0.00746889, -0.08898111, -0.03927629, ..., -0.04155045,
#          -0.04045466, -0.03456549], dtype=float32)),
#  (111,
#   'http://www.wikidata.org/entity/P737',
#   ['informed by', 'has influence', 'influenced by'],
#   array([ 0.00746889, -0.08530015, -0.01146756, ..., -0.02576495,
#           0.01431803, -0.02396838], dtype=float32)),
#  (112,
#   'http://www.wikidata.org/entity/P800',
#   ['literary works',
#    'bibliography',
#    'work',
#    'works',
#    'major works',
#    'famous works',
#    'significant works',
#    'known for',
#    'notable books',
#    'famous books',
#    'famous for',
#    'significance',
#    'representative work',
#    'artwork',
#    'notable work'],
#   array([ 0.00746889, -0.11120386,  0.08975589, ..., -0.02465496,
#          -0.01470058, -0.01274516], dtype=float32)),
#  (113,
#   'http://www.wikidata.org/entity/P81',
#   ['railway line',
#    'rapid transit line',
#    'line connected to',
#    'rail line connected to',
#    'is on',
#    'connecting line'],
#   array([ 0.00746889, -0.00994754,  0.02720047, ..., -0.05823435,
#           0.00154917, -0.01462658], dtype=float32)),
#  (114,
#   'http://www.wikidata.org/entity/P822',
#   ['mascot'],
#   array([ 0.00746889, -0.11935683,  0.01861135, ..., -0.06835024,
#          -0.06215507, -0.01624648], dtype=float32)),
#  (115,
#   'http://www.wikidata.org/entity/P826',
#   ['musical key', 'key of musical composition', 'tonality'],
#   array([ 0.00746889, -0.09504185,  0.13487108, ..., -0.03815362,
#          -0.04354132, -0.02586152], dtype=float32)),
#  (116,
#   'http://www.wikidata.org/entity/P84',
#   ['architecture firm', 'architect'],
#   array([ 0.00746889, -0.05023341,  0.05325206, ...,  0.00557685,
#           0.00211892, -0.0081402 ], dtype=float32)),
#  (117,
#   'http://www.wikidata.org/entity/P86',
#   ['songwriter',
#    'composed by',
#    'musical score by',
#    'music by',
#    'written by',
#    'composer'],
#   array([ 0.00746889, -0.0791524 ,  0.1004898 , ..., -0.04683314,
#           0.02037168, -0.01148337], dtype=float32)),
#  (118,
#   'http://www.wikidata.org/entity/P885',
#   ['river source',
#    'stream source',
#    'source of a stream',
#    'water source',
#    'water origin',
#    'river head',
#    'source of watercourse',
#    'origin of a watercourse'],
#   array([ 0.00746889, -0.10458165,  0.02325128, ..., -0.04159704,
#          -0.03629654, -0.02194456], dtype=float32)),
#  (119,
#   'http://www.wikidata.org/entity/P969',
#   ['address',
#    'street address',
#    'street without article',
#    'physical address',
#    'located at street address'],
#   array([ 0.00746889, -0.06301325, -0.01105576, ..., -0.03168726,
#           0.03481667, -0.03933041], dtype=float32)),
#  (120,
#   'http://www.wikidata.org/entity/P1001',
#   ['applies to jurisdiction',
#    'of jurisdiction',
#    'linked to jurisdiction',
#    'belongs to jurisdiction',
#    'jurisdiction',
#    'country of jurisdiction',
#    'valid in jurisdiction',
#    'applies to territorial jurisdiction',
#    'applied to jurisdiction'],
#   array([ 0.00746889, -0.03260348,  0.02242357, ...,  0.00092162,
#          -0.05534602, -0.03559341], dtype=float32)),
#  (121,
#   'http://www.wikidata.org/entity/P102',
#   ['member of political party',
#    'political party',
#    'party',
#    'member of',
#    'member of party',
#    'party membership'],
#   array([ 0.00746889, -0.10757729, -0.02620746, ..., -0.01318687,
#          -0.0330568 , -0.03491578], dtype=float32)),
#  (122,
#   'http://www.wikidata.org/entity/P1027',
#   ['conferred by',
#    'awarded by',
#    'bestowed by',
#    'given by',
#    'granted by',
#    'presented by'],
#   array([ 0.00746889, -0.07733814,  0.0815266 , ..., -0.03303924,
#           0.00246411, -0.01557483], dtype=float32)),
#  (123,
#   'http://www.wikidata.org/entity/P1028',
#   ['donated by', 'given by', 'bestowed by', 'gift from', 'donation from'],
#   array([ 0.00746889, -0.08397834,  0.1150314 , ...,  0.00134286,
#          -0.00378135, -0.01242692], dtype=float32)),
#  (124,
#   'http://www.wikidata.org/entity/P103',
#   ['native language',
#    'first language',
#    'mother tongue',
#    'language native',
#    'L1 speaker of'],
#   array([ 0.00746889, -0.09836838,  0.016137  , ..., -0.03667082,
#          -0.01578017, -0.01731042], dtype=float32)),
#  (125,
#   'http://www.wikidata.org/entity/P1037',
#   ['manager/director', 'art director', 'manager', 'director'],
#   array([ 0.00746889, -0.10312655,  0.01439906, ..., -0.03770284,
#          -0.02875092, -0.03395334], dtype=float32)),
#  (126,
#   'http://www.wikidata.org/entity/P1038',
#   ['relative', 'family', 'family member', 'kinsman', 'relation'],
#   array([ 0.00746889, -0.06040001,  0.00583392, ..., -0.03429636,
#          -0.0472539 , -0.04928674], dtype=float32)),
#  (127,
#   'http://www.wikidata.org/entity/P1050',
#   ['medical condition',
#    'disability',
#    'ailment',
#    'health problem',
#    'disorder',
#    'illness',
#    'disease',
#    'paralympic disability',
#    'health condition'],
#   array([ 0.00746889, -0.10996383, -0.04257701, ..., -0.06335653,
#          -0.03932592, -0.04272054], dtype=float32)),
#  (128,
#   'http://www.wikidata.org/entity/P1056',
#   ['product or material produced',
#    'material produced',
#    'produces',
#    'manufactures',
#    'makes',
#    'has product',
#    'product',
#    'maker of',
#    'manufacturer of',
#    'producer of',
#    'results in',
#    'creates',
#    'output',
#    'products',
#    'work produced',
#    'commodity'],
#   array([ 0.00746889, -0.10277254, -0.01976692, ..., -0.03544769,
#          -0.05267674, -0.01607729], dtype=float32)),
#  (129,
#   'http://www.wikidata.org/entity/P1057',
#   ['chromosome', 'on chromosome'],
#   array([ 0.00746889, -0.11930386, -0.06072804, ..., -0.08991538,
#          -0.05735777, -0.03296139], dtype=float32)),
#  (130,
#   'http://www.wikidata.org/entity/P1064',
#   ['track gauge', 'gauge'],
#   array([ 0.00746889, -0.13236079, -0.06872479, ..., -0.09991686,
#          -0.05536786, -0.0470889 ], dtype=float32)),
#  (131,
#   'http://www.wikidata.org/entity/P1066',
#   ['student of',
#    'teacher',
#    'professor',
#    'pupil of',
#    'supervisor',
#    'academic supervisor',
#    'disciple of',
#    'studied under',
#    'master',
#    'mentor',
#    'advisor',
#    'tutor'],
#   array([ 0.00746889, -0.09434333,  0.02144702, ..., -0.02409578,
#          -0.04049577, -0.03376247], dtype=float32)),
#  (132,
#   'http://www.wikidata.org/entity/P1071',
#   ['location of final assembly',
#    'assembly location',
#    'place built',
#    'place made',
#    'location of origin',
#    'place of origin',
#    'made in',
#    'minted at',
#    'mint'],
#   array([ 0.00746889, -0.0890751 , -0.01778769, ..., -0.05175283,
#          -0.03755915, -0.00061748], dtype=float32)),
#  (133,
#   'http://www.wikidata.org/entity/P108',
#   ['employer',
#    'workplace',
#    'employed by',
#    'works at',
#    'working for',
#    'worked for',
#    'works for',
#    'worked at'],
#   array([ 0.00746889, -0.10461523,  0.02955575, ..., -0.03709388,
#          -0.04351095, -0.03233599], dtype=float32)),
#  (134,
#   'http://www.wikidata.org/entity/P1080',
#   ['from fictional universe',
#    'from universe',
#    'universe',
#    'featured in universe',
#    'appears in universe',
#    'fictional universe where entity is from',
#    'from mythology',
#    'mythology',
#    'continuity',
#    'in continuity',
#    'cycle',
#    'in cycle',
#    'in world of',
#    'story cycle',
#    'from narrative'],
#   array([ 0.00746889, -0.10815045,  0.00315523, ..., -0.04986321,
#          -0.01679868, -0.0283492 ], dtype=float32)),
#  (135,
#   'http://www.wikidata.org/entity/P110',
#   ['illustrator', 'illustration by', 'illustrated by'],
#   array([ 0.00746889, -0.08143417,  0.02212553, ..., -0.07437987,
#           0.00338603, -0.02244877], dtype=float32)),
#  (136,
#   'http://www.wikidata.org/entity/P118',
#   ['league', 'division', 'sports league'],
#   array([ 0.00746889, -0.10322019, -0.03534901, ...,  0.03443328,
#          -0.01189877, -0.03110619], dtype=float32)),
#  (137,
#   'http://www.wikidata.org/entity/P1192',
#   ['connecting service'],
#   array([ 0.00746889, -0.10161031,  0.13248658, ..., -0.02284921,
#          -0.00663287, -0.06184948], dtype=float32)),
#  (138,
#   'http://www.wikidata.org/entity/P1196',
#   ['manner of death',
#    'circumstance of death',
#    'type of death',
#    'death manner',
#    'death type'],
#   array([ 0.00746889, -0.07776888, -0.0237633 , ..., -0.06013709,
#          -0.05832132, -0.02939128], dtype=float32)),
#  (139,
#   'http://www.wikidata.org/entity/P121',
#   ['item operated',
#    'fleet',
#    'aircraft in fleet',
#    'aircraft operated',
#    'equipment operated',
#    'facility operated',
#    'service operated',
#    'operator of',
#    'operated',
#    'operates',
#    'eq',
#    'acop',
#    'aircraft carried',
#    'item used',
#    'uses item'],
#   array([ 0.00746889, -0.0907164 ,  0.00348662, ..., -0.04998358,
#          -0.05531274, -0.03142532], dtype=float32)),
#  (140,
#   'http://www.wikidata.org/entity/P126',
#   ['maintained by',
#    'maintenance',
#    'administered by',
#    'maintainer',
#    'custodian',
#    'administrator'],
#   array([ 0.00746889, -0.1129126 , -0.02444499, ..., -0.08097877,
#          -0.04059677, -0.03205316], dtype=float32)),
#  (141,
#   'http://www.wikidata.org/entity/P129',
#   ['physically interacts with'],
#   array([ 0.00746889, -0.10965479, -0.00160275, ..., -0.07117449,
#          -0.05297119, -0.03656542], dtype=float32)),
#  (142,
#   'http://www.wikidata.org/entity/P1340',
#   ['eye color', 'eye colour', 'eyecolor', 'eyecolour'],
#   array([ 0.00746889, -0.09070608,  0.01561232, ..., -0.08260216,
#          -0.03315877, -0.04063826], dtype=float32)),
#  (143,
#   'http://www.wikidata.org/entity/P1344',
#   ['participant of',
#    'took part',
#    'took part in',
#    'participant in',
#    'participated in',
#    'competed in',
#    'participant of event'],
#   array([ 0.00746889, -0.11156987, -0.01358857, ..., -0.03467052,
#          -0.0607294 , -0.02431748], dtype=float32)),
#  (144,
#   'http://www.wikidata.org/entity/P1346',
#   ['winner', 'won by', 'victor', 'champion', 'winners'],
#   array([ 0.00746889, -0.08479425,  0.04694447, ..., -0.05581521,
#          -0.00556481, -0.03128774], dtype=float32)),
#  (145,
#   'http://www.wikidata.org/entity/P1376',
#   ['capital of', 'county seat of', 'county seat for'],
#   array([ 0.00746889, -0.12642509,  0.00928318, ..., -0.01805618,
#          -0.05462859, -0.01627286], dtype=float32)),
#  (146,
#   'http://www.wikidata.org/entity/P1382',
#   ['partially coincident with',
#    'partially overlaps',
#    'partial concurrency',
#    'concurrent with',
#    'concurrency',
#    'overlapping with',
#    'partially include',
#    'partially in',
#    'coincident with'],
#   array([ 0.00746889, -0.12647957, -0.02640726, ..., -0.08261435,
#          -0.0557429 , -0.03745903], dtype=float32)),
#  (147,
#   'http://www.wikidata.org/entity/P1383',
#   ['contains settlement', 'populated places within'],
#   array([ 0.00746889, -0.1303378 ,  0.01962653, ..., -0.01858419,
#          -0.03572604,  0.00137005], dtype=float32)),
#  (148,
#   'http://www.wikidata.org/entity/P1389',
#   ['product certification'],
#   array([ 0.00746889, -0.07461821, -0.00421137, ..., -0.01887558,
#          -0.04302675, -0.00918528], dtype=float32)),
#  (149,
#   'http://www.wikidata.org/entity/P1399',
#   ['convicted of', 'guilty of', 'found guilty of'],
#   array([ 0.00746889, -0.08823177, -0.02731123, ..., -0.0189208 ,
#          -0.04911916, -0.02411097], dtype=float32)),
#  (150,
#   'http://www.wikidata.org/entity/P1403',
#   ['original combination', 'protonym'],
#   array([ 0.00746889, -0.08646245,  0.00068759, ..., -0.08359145,
#          -0.04613895, -0.01797431], dtype=float32)),
#  (151,
#   'http://www.wikidata.org/entity/P1411',
#   ['nominated for', 'nominee for', 'nomination received'],
#   array([ 0.00746889, -0.11364005,  0.05295813, ..., -0.05307858,
#          -0.04170178, -0.02836934], dtype=float32)),
#  (152,
#   'http://www.wikidata.org/entity/P1427',
#   ['start point',
#    'flight origin',
#    'start location',
#    'from',
#    'journey start',
#    'journey origin',
#    'launch location',
#    'launch site',
#    'launch pad'],
#   array([ 0.00746889, -0.09666979, -0.03182364, ..., -0.04155178,
#          -0.02183265, -0.0194308 ], dtype=float32)),
#  (153,
#   'http://www.wikidata.org/entity/P1433',
#   ['published in',
#    'on the tracklist of',
#    'venue',
#    'part of work',
#    'published in journal'],
#   array([ 0.00746889, -0.10744937,  0.00383477, ..., -0.04640889,
#          -0.02464196, -0.0108427 ], dtype=float32)),
#  (154,
#   'http://www.wikidata.org/entity/P1434',
#   ['takes place in fictional universe',
#    'describes fictional universe',
#    'fictional universe described',
#    'universe described',
#    'universe featured',
#    'set in fictional universe',
#    'describes the fictional universe',
#    'continuity'],
#   array([ 0.00746889, -0.08633321,  0.04550989, ..., -0.05630203,
#           0.00648443, -0.01934438], dtype=float32)),
#  (155,
#   'http://www.wikidata.org/entity/P1435',
#   ['heritage designation',
#    'designation',
#    'listing',
# ...
#    'plays for',
#    'teams played for',
#    'of team',
#    'club played for',
#    'player of',
#    'part of team'],
#   array([ 0.00746889, -0.09588297,  0.00084733, ..., -0.01207617,
#          -0.05758943, -0.03261099], dtype=float32)),
#  (256,
#   'http://www.wikidata.org/entity/P551',
#   ['residence',
#    'lived in',
#    'resident in',
#    'lives in',
#    'hometown',
#    'home town',
#    'place of residence'],
#   array([ 0.00746889, -0.09738101, -0.01435576, ..., -0.03527829,
#          -0.02819133, -0.04049257], dtype=float32)),
#  (257,
#   'http://www.wikidata.org/entity/P559',
#   ['terminus', 'termini', 'end point', 'terminating connection'],
#   array([ 0.00746889, -0.10604287, -0.03590193, ..., -0.07822043,
#          -0.04401397, -0.03771159], dtype=float32)),
#  (258,
#   'http://www.wikidata.org/entity/P560',
#   ['direction', 'facing'],
#   array([ 0.00746889, -0.11806804, -0.05738187, ..., -0.08159873,
#          -0.04819894, -0.03831089], dtype=float32)),
#  (259,
#   'http://www.wikidata.org/entity/P566',
#   ['basionym'],
#   array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#          -0.06125114, -0.04683771], dtype=float32)),
#  (260,
#   'http://www.wikidata.org/entity/P608',
#   ['exhibition history'],
#   array([ 0.00746889, -0.12569919,  0.04942005, ...,  0.01047989,
#          -0.00977623, -0.00563311], dtype=float32)),
#  (261,
#   'http://www.wikidata.org/entity/P609',
#   ['terminus location',
#    'destination',
#    'departure point',
#    'from',
#    'to',
#    'between'],
#   array([ 0.00746889, -0.08883855, -0.01782761, ..., -0.05712854,
#          -0.0298274 , -0.0238302 ], dtype=float32)),
#  (262,
#   'http://www.wikidata.org/entity/P610',
#   ['highest point',
#    'highest peak',
#    'zenith',
#    'summit',
#    'extreme point highest'],
#   array([ 0.00746889, -0.07806122,  0.04839835, ..., -0.0154065 ,
#          -0.03630566,  0.02401295], dtype=float32)),
#  (263,
#   'http://www.wikidata.org/entity/P611',
#   ['religious order', 'order'],
#   array([ 0.00746889, -0.04391029,  0.02865179, ..., -0.04125577,
#           0.00182869, -0.02075358], dtype=float32)),
#  (264,
#   'http://www.wikidata.org/entity/P629',
#   ['edition or translation of', 'edition of', 'translation of'],
#   array([ 0.00746889, -0.09239893, -0.00964895, ..., -0.03408875,
#          -0.0014395 , -0.01216516], dtype=float32)),
#  (265,
#   'http://www.wikidata.org/entity/P636',
#   ['route of administration'],
#   array([ 0.00746889, -0.1136563 ,  0.03030581, ...,  0.00268124,
#          -0.06475541,  0.00628042], dtype=float32)),
#  (266,
#   'http://www.wikidata.org/entity/P647',
#   ['drafted by'],
#   array([ 0.00746889, -0.08315081, -0.01273686, ...,  0.02463687,
#           0.02148831, -0.0126447 ], dtype=float32)),
#  (267,
#   'http://www.wikidata.org/entity/P655',
#   ['translator', 'translated by'],
#   array([ 0.00746889, -0.09867227,  0.02827215, ..., -0.02313377,
#           0.04317325, -0.01159896], dtype=float32)),
#  (268,
#   'http://www.wikidata.org/entity/P658',
#   ['tracklist', 'track list', 'track listing', 'list of tracks', 'songs'],
#   array([ 7.4688881e-03, -1.3161966e-01,  5.2276253e-05, ...,
#          -5.7251044e-02, -2.5336534e-02, -3.7943643e-02], dtype=float32)),
#  (269,
#   'http://www.wikidata.org/entity/P664',
#   ['organizer', 'organiser', 'event producer'],
#   array([ 0.00746889, -0.1292169 , -0.05246483, ..., -0.07310779,
#          -0.04663146, -0.03654133], dtype=float32)),
#  (270,
#   'http://www.wikidata.org/entity/P669',
#   ['located on street',
#    'is on',
#    'street',
#    'square',
#    'road',
#    'address street',
#    'on street'],
#   array([ 0.00746889, -0.10602216, -0.02114947, ..., -0.05959889,
#           0.00237435, -0.02746429], dtype=float32)),
#  (271,
#   'http://www.wikidata.org/entity/P674',
#   ['characters'],
#   array([ 0.00746889, -0.13863035, -0.06401081, ..., -0.09271191,
#          -0.04852505, -0.03852709], dtype=float32)),
#  (272,
#   'http://www.wikidata.org/entity/P680',
#   ['molecular function'],
#   array([ 0.00746889, -0.06667592,  0.00768205, ..., -0.0814857 ,
#          -0.06475541, -0.03094646], dtype=float32)),
#  (273,
#   'http://www.wikidata.org/entity/P681',
#   ['cell component', 'subcellular localization'],
#   array([ 0.00746889, -0.12272236, -0.03405198, ..., -0.09359629,
#          -0.04658266, -0.02795182], dtype=float32)),
#  (274,
#   'http://www.wikidata.org/entity/P682',
#   ['biological process'],
#   array([ 0.00746889,  0.03187265, -0.0206883 , ..., -0.07618638,
#          -0.03293724, -0.01944356], dtype=float32)),
#  (275,
#   'http://www.wikidata.org/entity/P684',
#   ['ortholog'],
#   array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#          -0.06125114, -0.04683771], dtype=float32)),
#  (276,
#   'http://www.wikidata.org/entity/P688',
#   ['encodes', 'codes for'],
#   array([ 0.00746889, -0.12207395, -0.02049602, ..., -0.06881712,
#          -0.01876467, -0.03364338], dtype=float32)),
#  (277,
#   'http://www.wikidata.org/entity/P689',
#   ['afflicts'],
#   array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#          -0.06125114, -0.04683771], dtype=float32)),
#  (278,
#   'http://www.wikidata.org/entity/P702',
#   ['encoded by'],
#   array([ 0.00746889, -0.07695843, -0.00368243, ..., -0.0890227 ,
#           0.00246412, -0.02083005], dtype=float32)),
#  (279,
#   'http://www.wikidata.org/entity/P703',
#   ['found in taxon', 'species'],
#   array([ 0.00746889, -0.13343476,  0.01732828, ..., -0.09126101,
#          -0.06393128, -0.01951968], dtype=float32)),
#  (280,
#   'http://www.wikidata.org/entity/P706',
#   ['located on terrain feature',
#    'takes place in',
#    'on geographical feature',
#    'on natural feature',
#    'is on',
#    'is in',
#    'location (terrain feature)',
#    'loc (terr)'],
#   array([ 0.00746889, -0.0970468 ,  0.00943915, ..., -0.06001402,
#          -0.04440185, -0.01038082], dtype=float32)),
#  (281,
#   'http://www.wikidata.org/entity/P708',
#   ['diocese'],
#   array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#          -0.06125114, -0.04683771], dtype=float32)),
#  (282,
#   'http://www.wikidata.org/entity/P725',
#   ['voice actor',
#    'voice dubber',
#    'dubbed by',
#    'VO',
#    'voiced by',
#    'CV',
#    'VA',
#    'voice actress',
#    'voice actors',
#    'voice actresses',
#    'seiyu'],
#   array([ 0.00746889, -0.11385827,  0.0089396 , ..., -0.06365084,
#          -0.02953678, -0.02067945], dtype=float32)),
#  (283,
#   'http://www.wikidata.org/entity/P734',
#   ['family name', 'last name', 'has surname', 'surname'],
#   array([ 0.00746889, -0.08167897, -0.03235358, ..., -0.03502839,
#          -0.04005346, -0.02269056], dtype=float32)),
#  (284,
#   'http://www.wikidata.org/entity/P735',
#   ['given name',
#    'forename',
#    'first name',
#    'personal name',
#    'middle name',
#    'Christian name'],
#   array([ 0.00746889, -0.0585707 , -0.00147232, ..., -0.03059936,
#          -0.01797901, -0.0268485 ], dtype=float32)),
#  (285,
#   'http://www.wikidata.org/entity/P739',
#   ['ammunition', 'cartridge', 'ammo'],
#   array([ 0.00746889, -0.12728208, -0.06788646, ..., -0.07794871,
#          -0.06241924, -0.0385718 ], dtype=float32)),
#  (286,
#   'http://www.wikidata.org/entity/P740',
#   ['location of formation',
#    'originates from',
#    'comes from',
#    'place of foundation',
#    'founded in',
#    'formation location',
#    'source location of group/organisation',
#    'formed in',
#    'from',
#    'place of formation'],
#   array([ 0.00746889, -0.10447391,  0.00876802, ..., -0.03177325,
#          -0.02938755, -0.01796821], dtype=float32)),
#  (287,
#   'http://www.wikidata.org/entity/P748',
#   ['appointed by'],
#   array([ 0.00746889, -0.07695843, -0.00368243, ..., -0.0890227 ,
#           0.00246412, -0.02083005], dtype=float32)),
#  (288,
#   'http://www.wikidata.org/entity/P749',
#   ['parent organization',
#    'owned by (company or organization)',
#    'subsidiary of',
#    'parent company',
#    'parent organisation',
#    'owned by (company or organisation)',
#    'holding',
#    'holding company',
#    'part of',
#    'parent unit',
#    'parent agency',
#    'superior formation'],
#   array([ 0.00746889, -0.04419159, -0.00830397, ..., -0.03129605,
#          -0.03521366, -0.01763652], dtype=float32)),
#  (289,
#   'http://www.wikidata.org/entity/P750',
#   ['distributor', 'distributed by'],
#   array([ 0.00746889, -0.111145  , -0.00757582, ..., -0.07562139,
#          -0.02939352, -0.02847409], dtype=float32)),
#  (290,
#   'http://www.wikidata.org/entity/P765',
#   ['surface played on'],
#   array([ 0.00746889, -0.10098825, -0.05404265, ..., -0.04552004,
#          -0.05346438, -0.01908506], dtype=float32)),
#  (291,
#   'http://www.wikidata.org/entity/P767',
#   ['contributor(s) to the creative work',
#    'assistant',
#    'contributor',
#    'collaborator',
#    'contributor(s) to the subject'],
#   array([ 0.00746889, -0.10006354,  0.00987714, ..., -0.03544185,
#          -0.02434764, -0.03304499], dtype=float32)),
#  (292,
#   'http://www.wikidata.org/entity/P768',
#   ['electoral district',
#    'constituency',
#    'ward',
#    'riding',
#    'electoral area',
#    'electorate'],
#   array([ 0.00746889, -0.12420145, -0.04501472, ..., -0.06236782,
#          -0.04848105, -0.03325652], dtype=float32)),
#  (293,
#   'http://www.wikidata.org/entity/P769',
#   ['significant drug interaction', 'drug interaction'],
#   array([ 0.00746889, -0.12784249, -0.02798472, ..., -0.07192548,
#           0.01324631, -0.0136589 ], dtype=float32)),
#  (294,
#   'http://www.wikidata.org/entity/P780',
#   ['symptoms', 'signs'],
#   array([ 0.00746889, -0.09241162, -0.03142235, ..., -0.04179695,
#          -0.05281638, -0.02269132], dtype=float32)),
#  (295,
#   'http://www.wikidata.org/entity/P790',
#   ['approved by'],
#   array([ 0.00746889, -0.08584135,  0.05684885, ..., -0.04885448,
#           0.01599792,  0.01446875], dtype=float32)),
#  (296,
#   'http://www.wikidata.org/entity/P793',
#   ['significant event',
#    'key event',
#    'key incident',
#    'significant incident',
#    'notable event',
#    'notable incident',
#    'major event',
#    'big event',
#    'main events',
#    'fate',
#    'outcome',
#    'event',
#    'known for'],
#   array([ 0.00746889, -0.10949964,  0.00639172, ..., -0.07278933,
#          -0.05095717, -0.01797626], dtype=float32)),
#  (297,
#   'http://www.wikidata.org/entity/P802',
#   ['student',
#    'students',
#    'teacher of',
#    'pupil',
#    'pupils',
#    'disciple',
#    'disciples'],
#   array([ 0.00746889, -0.09887188, -0.00936994, ..., -0.05502438,
#          -0.05438566, -0.03276478], dtype=float32)),
#  (298,
#   'http://www.wikidata.org/entity/P805',
#   ['statement is subject of',
#    'article',
#    'artfor',
#    'subject of the claim',
#    'subject of the statement',
#    'dedicated article',
#    'subject of',
#    'dedicated item'],
#   array([ 0.00746889, -0.08175836,  0.0092122 , ..., -0.04478839,
#          -0.03911033, -0.01663896], dtype=float32)),
#  (299,
#   'http://www.wikidata.org/entity/P812',
#   ['academic major', 'major', 'academic field', 'academic subject', 'subject'],
#   array([ 0.00746889, -0.10039185, -0.00446576, ..., -0.02667372,
#          -0.03279581, -0.01785332], dtype=float32)),
#  (300,
#   'http://www.wikidata.org/entity/P825',
#   ['dedicated to', 'dedication', 'tribute to', 'dedicatee'],
#   array([ 0.00746889, -0.09987919,  0.0769783 , ..., -0.0568281 ,
#          -0.04738564, -0.0355256 ], dtype=float32)),
#  (301,
#   'http://www.wikidata.org/entity/P828',
#   ['has cause',
#    'cause',
#    'has causes',
#    'has underlying cause',
#    'underlying cause',
#    'ultimate cause',
#    'ultimate causes',
#    'initial cause',
#    'effect of',
#    'outcome of',
#    'result of',
#    'has reason',
#    'reason',
#    'caused by',
#    'implied by',
#    'because',
#    'due to'],
#   array([ 0.00746889, -0.07394792, -0.03685539, ..., -0.03094436,
#          -0.04226905, -0.02211624], dtype=float32)),
#  (302,
#   'http://www.wikidata.org/entity/P837',
#   ['day in year for periodic occurrence',
#    'day of periodic occurrence',
#    'day in year',
#    'day',
#    'date',
#    'recurring event',
#    'periodic occurrence',
#    'takes place on',
#    'takes places during'],
#   array([ 0.00746889, -0.0891394 , -0.03334217, ..., -0.03244488,
#          -0.05479202, -0.01625732], dtype=float32)),
#  (303,
#   'http://www.wikidata.org/entity/P840',
#   ['narrative location',
#    'setting location',
#    'narrative set in',
#    'location of narrative'],
#   array([ 0.00746889, -0.10331039, -0.01727606, ..., -0.05841726,
#          -0.00965441, -0.03016955], dtype=float32)),
#  (304,
#   'http://www.wikidata.org/entity/P841',
#   ['feast day'],
#   array([ 0.00746889, -0.10223781,  0.00309712, ..., -0.03776111,
#          -0.06475541, -0.00564627], dtype=float32)),
#  (305,
#   'http://www.wikidata.org/entity/P85',
#   ['anthem', 'national anthem', 'march', 'official song'],
#   array([ 0.00746889, -0.11217664,  0.02019155, ..., -0.04742768,
#          -0.00773858, -0.01813447], dtype=float32)),
#  (306,
#   'http://www.wikidata.org/entity/P859',
#   ['sponsor', 'funded by', 'funder', 'patron', 'endorsed by'],
#   array([ 0.00746889, -0.11941095, -0.01331328, ..., -0.08598075,
#          -0.02772938, -0.02541546], dtype=float32)),
#  (307,
#   'http://www.wikidata.org/entity/P870',
#   ['instrumentation'],
#   array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#          -0.06125114, -0.04683771], dtype=float32)),
#  (308,
#   'http://www.wikidata.org/entity/P88',
#   ['commissioned by',
#    'client',
#    'commissioner',
#    'made for',
#    'built for',
#    'Developer'],
#   array([ 0.00746889, -0.1034722 , -0.01134579, ..., -0.04971673,
#          -0.0381128 , -0.01505808], dtype=float32)),
#  (309,
#   'http://www.wikidata.org/entity/P880',
#   ['CPU', 'central processing unit'],
#   array([ 0.00746889, -0.1164088 , -0.03268316, ..., -0.07421964,
#          -0.0546762 , -0.02131584], dtype=float32)),
#  (310,
#   'http://www.wikidata.org/entity/P915',
#   ['filming location',
#    'location of filming',
#    'location where filmed',
#    'studio where filmed',
#    'place of filming',
#    'place where filmed',
#    'recorded at',
#    'filmed at',
#    'shooting location'],
#   array([ 0.00746889, -0.09535197, -0.02371134, ..., -0.03988474,
#          -0.02091144, -0.01753663], dtype=float32)),
#  (311,
#   'http://www.wikidata.org/entity/P921',
#   ['main subject',
#    'index term',
#    'topic of work',
#    'main topic',
#    'aboutness',
#    'about',
#    'topic',
#    'subject',
#    'subject heading',
#    'mainly about',
#    'theme',
#    'main issue',
#    'main thing',
#    'keyword',
#    'is about',
#    'primary topic',
#    'primary subject',
#    'describes'],
#   array([ 0.00746889, -0.08240518, -0.03228536, ..., -0.05303029,
#          -0.04778656, -0.02338589], dtype=float32)),
#  (312,
#   'http://www.wikidata.org/entity/P931',
#   ['place served by transport hub',
#    'serves city',
#    'city served',
#    'train station serves'],
#   array([ 0.00746889, -0.10535565,  0.05346248, ..., -0.02873763,
#           0.0083831 , -0.01456732], dtype=float32)),
#  (313,
#   'http://www.wikidata.org/entity/P937',
#   ['work location',
#    'workplace',
#    'work location',
#    'place of activity',
#    'active in',
#    'location of work',
#    'place of work'],
#   array([ 0.00746889, -0.1117745 ,  0.01946465, ..., -0.0470681 ,
#          -0.04148372, -0.02852763], dtype=float32)),
#  (314,
#   'http://www.wikidata.org/entity/P941',
#   ['inspired by', 'source of inspiration', 'inspiration'],
#   array([ 0.00746889, -0.11124247,  0.04653227, ..., -0.05882928,
#           0.00158732, -0.0297196 ], dtype=float32)),
#  (315,
#   'http://www.wikidata.org/entity/P97',
#   ['noble title',
#    'peerage',
#    'title (hereditary)',
#    'hereditary title',
#    'royal title'],
#   array([ 0.00746889, -0.02066112,  0.07023342, ..., -0.01719416,
#          -0.0340033 , -0.04507201], dtype=float32)),
#  (316,
#   'http://www.wikidata.org/entity/P974',
#   ['tributary'],
#   array([ 0.00746889, -0.13024533, -0.03639873, ..., -0.05730022,
#          -0.04186886, -0.00910007], dtype=float32)),
#  (317,
#   'http://www.wikidata.org/entity/P98',
#   ['editor', 'compiler', 'edited by', 'compiled by'],
#   array([ 0.00746889, -0.09868953, -0.01042   , ..., -0.07266217,
#           0.00637878, -0.03508582], dtype=float32)),
#  (318,
#   'http://www.wikidata.org/entity/P991',
#   ['successful candidate', 'elected person', 'winner of election'],
#   array([ 0.00746889, -0.09075499,  0.0326615 , ..., -0.02492922,
#          -0.02665507, -0.02976383], dtype=float32))]

# %%
pkl.dump(uri_topic_dict, open('uri_topic_dict.pkl', 'wb') )

# %%
uri_topic_dict = pkl.load(open('uri_topic_dict.pkl', 'rb'))
print(uri_topic_dict)
# Out:
# [(0, 'http://www.wikidata.org/entity/P101', ['field of study', 'fields', 'discipline', 'subject', 'area', 'specialism', 'domain', 'academic discipline', 'scientific discipline', 'academic subject', 'academic area', 'scientific area', 'FOW', 'field of work'], array([ 0.00746889, -0.09179498,  0.00967923, ..., -0.03022508,
#        -0.05071909, -0.02850063], dtype=float32)), (1, 'http://www.wikidata.org/entity/P1029', ['crew member'], array([ 0.00746889, -0.09595255, -0.02173634, ..., -0.01069365,
#        -0.05936687, -0.06587837], dtype=float32)), (2, 'http://www.wikidata.org/entity/P1040', ['editor', 'edited by', 'film editor'], array([ 0.00746889, -0.09455415,  0.01290073, ..., -0.04508448,
#         0.04699417, -0.04150699], dtype=float32)), (3, 'http://www.wikidata.org/entity/P105', ['taxonomic rank', 'rank', 'type of taxon', 'taxon rank'], array([ 0.00746889, -0.12191994,  0.05286136, ..., -0.02282107,
#        -0.02680972, -0.0277157 ], dtype=float32)), (4, 'http://www.wikidata.org/entity/P106', ['profession', 'job', 'work', 'career', 'employment', 'craft', 'occupation'], array([ 0.00746889, -0.09369477,  0.00406455, ..., -0.02342394,
#        -0.05456912, -0.03570878], dtype=float32)), (5, 'http://www.wikidata.org/entity/P1082', ['inhabitants', 'human population', 'population'], array([ 0.00746889, -0.11678901, -0.02201126, ..., -0.03053595,
#        -0.03637259, -0.0042838 ], dtype=float32)), (6, 'http://www.wikidata.org/entity/P1083', ['number of seats', 'seats', 'seating capacity', 'capacity', 'complement', 'crew', 'maximum capacity'], array([ 0.00746889, -0.1090322 ,  0.03415957, ..., -0.06161226,
#        -0.05761572, -0.02552371], dtype=float32)), (7, 'http://www.wikidata.org/entity/P1101', ['number of floors', 'storeys', 'stories', 'floors above ground'], array([ 0.00746889, -0.14113352,  0.03164708, ..., -0.03479409,
#         0.02442883, -0.00622076], dtype=float32)), (8, 'http://www.wikidata.org/entity/P112', ['is founded by', 'founded', 'co-founder', 'founders', 'founder', 'co-founded', 'was founded by', 'established by', 'founded by'], array([ 0.00746889, -0.09020272,  0.01062813, ..., -0.00406058,
#         0.00302944, -0.03505066], dtype=float32)), (9, 'http://www.wikidata.org/entity/P1128', ['number of employees', 'workers', 'personnel', 'employee count', 'employees'], array([ 0.00746889, -0.11115783, -0.02631274, ..., -0.02936626,
#        -0.05395389, -0.01726099], dtype=float32)), (10, 'http://www.wikidata.org/entity/P113', ['hub', 'hub airport', 'airline hub'], array([ 0.00746889, -0.11049795,  0.06887881, ..., -0.02844986,
#         0.01697187, -0.01789737], dtype=float32)), (11, 'http://www.wikidata.org/entity/P1142', ['ideology', 'political ideology'], array([ 0.00746889, -0.06506085, -0.06596207, ..., -0.01853116,
#        -0.00541435, -0.02311311], dtype=float32)), (12, 'http://www.wikidata.org/entity/P115', ['ground', 'home field', 'arena', 'home ground', 'stadium', 'ballpark', 'home water', 'home venue'], array([ 0.00746889, -0.11702027, -0.00612974, ..., -0.05891509,
#        -0.02755768, -0.02618528], dtype=float32)), (13, 'http://www.wikidata.org/entity/P1174', ['visitors per year'], array([ 0.00746889, -0.12081139,  0.08118473, ...,  0.00408778,
#        -0.05658534,  0.00345761], dtype=float32)), (14, 'http://www.wikidata.org/entity/P119', ['burial place', 'resting place', 'place of grave', 'buried in', 'grave at', 'location of burial', 'tomb', 'interment', 'place of interment', 'buried at', 'place of burial'], array([ 0.00746889, -0.10639884, -0.00808805, ..., -0.04070521,
#        -0.03833726, -0.03714211], dtype=float32)), (15, 'http://www.wikidata.org/entity/P122', ['type of government', 'form of government', 'government', 'basic form of government'], array([ 0.00746889, -0.08988998,  0.01207556, ..., -0.00359307,
#        -0.060884  , -0.00235663], dtype=float32)), (16, 'http://www.wikidata.org/entity/P123', ['book publisher', 'video game publisher', 'software publisher', 'publishing house', 'published by', 'board game publisher', 'publisher'], array([ 0.00746889, -0.09961899,  0.01540328, ..., -0.01098731,
#         0.04296982, -0.02828511], dtype=float32)), (17, 'http://www.wikidata.org/entity/P127', ['is owned by', 'owner', 'belongs to', 'shareholder', 'stockholder', 'shareholders', 'stockholders', 'owners', 'provenance', 'owned by'], array([ 0.00746889, -0.0232072 , -0.0124549 , ..., -0.01527017,
#        -0.02028242, -0.03585616], dtype=float32)), (18, 'http://www.wikidata.org/entity/P1303', ['plays', 'musical instrument', 'instrument'], array([ 0.00746889, -0.0162352 ,  0.1047081 , ..., -0.0455931 ,
#        -0.06475541, -0.00867746], dtype=float32)), (19, 'http://www.wikidata.org/entity/P1308', ['incumbent', 'officeholder'], array([ 0.00746889, -0.07011655, -0.01331416, ..., -0.03767011,
#        -0.04040495, -0.05860477], dtype=float32)), (20, 'http://www.wikidata.org/entity/P131', ['located in the administrative unit', 'located in administrative unit', 'is in administrative unit', 'is located in', 'is in the state of', 'is in the province of', 'is in the county of', 'is in the district of', 'is in the department of', 'is in the region of', 'is in the borough of', 'is in the city of', 'is in the town of', 'is in the village of', 'is in the municipality of', 'is in the territory of', 'is in the prefecture of', 'is in the voivodeship of', 'is in the Indian reservation of', 'is in the Indian reserve of', 'is in the ward of', 'is in the administrative region of', 'is in the settlement of', 'is in the local government area of', 'is in the rural city of', 'is in the shire of', 'happens in', 'is in the commune of', 'in administrative unit', 'in', 'is in the administrative unit', 'administrative territorial entity', 'city', 'town', 'state', 'Indian reservation', 'in the administrative unit', 'locality', 'is in the parish of', 'location (administrative territorial entity)', 'is in the principal area of', 'based in', 'located in the administrative territorial entity', 'located in the territorial entity', 'region', 'located in area'], array([ 0.00746889, -0.10035761,  0.0107002 , ..., -0.01955368,
#        -0.03936182, -0.00059711], dtype=float32)), (21, 'http://www.wikidata.org/entity/P1313', ['office of head of government', 'position of head of government', 'position held by head of government', 'title of head of government', 'office held by head of government'], array([ 0.00746889, -0.07614501,  0.0074209 , ..., -0.00359307,
#        -0.03278311, -0.00235663], dtype=float32)), (22, 'http://www.wikidata.org/entity/P135', ['school', 'trend', 'movement'], array([ 0.00746889, -0.1318391 , -0.04368946, ..., -0.04859178,
#        -0.03640259, -0.03866735], dtype=float32)), (23, 'http://www.wikidata.org/entity/P136', ['music genre', 'film genre', 'artistic genre', 'literary genre', 'kind of music', 'type of film', 'genre of music', 'type of music', 'genre'], array([ 0.00746889, -0.11491671,  0.12136432, ..., -0.04867068,
#        -0.00116275, -0.04549991], dtype=float32)), (24, 'http://www.wikidata.org/entity/P1365', ['forefather', 'previous job holder', 'replaced', 'preceded by', 'succeeds', 'after', 'predecessor', 'supersedes', 'continues from', 'replaces'], array([ 0.00746889, -0.03690854,  0.00075284, ..., -0.04466995,
#        -0.03505586, -0.0316157 ], dtype=float32)), (25, 'http://www.wikidata.org/entity/P137', ['service operator', 'facility operator', 'operated by', 'managed by', 'administrator', 'item operator', 'user', 'operator'], array([ 0.00746889, -0.06273175,  0.02421567, ..., -0.03576022,
#        -0.02512793, -0.02627853], dtype=float32)), (26, 'http://www.wikidata.org/entity/P138', ['eponym', 'named for', 'namesake', 'etymology', 'toponym', 'name after', 'named after'], array([ 0.00746889, -0.10393412,  0.00954461, ..., -0.02959974,
#        -0.0168234 , -0.02161496], dtype=float32)), (27, 'http://www.wikidata.org/entity/P140', ['faith', 'religious affiliation', 'life stance', 'denomination', 'religion'], array([ 0.00746889, -0.04945031,  0.02897425, ..., -0.00489116,
#        -0.01283371, -0.04476549], dtype=float32)), (28, 'http://www.wikidata.org/entity/P1408', ['city of license', 'community of license', 'licensed to broadcast to'], array([ 0.00746889, -0.11682684,  0.09541557, ..., -0.0048597 ,
#         0.00229425, -0.01816681], dtype=float32)), (29, 'http://www.wikidata.org/entity/P1412', ['languages spoken', 'language spoken', 'language of expression', 'languages of expression', 'languages signed', 'language signed', 'language written', 'language read', 'language used', 'language', 'speaks language', 'writes language', 'signs language', 'uses language', 'wrote language', 'spoke language', 'used language', 'signed language', 'second language', 'languages spoken', ' written', ' or signed', 'language(s) spoken', ' written or signed', 'languages spoken, written or signed'], array([ 0.00746889, -0.10217965,  0.02561154, ...,  0.003572  ,
#        -0.00536312, -0.00718582], dtype=float32)), (30, 'http://www.wikidata.org/entity/P1416', ['affiliated with', 'affiliation'], array([ 0.00746889, -0.10511345,  0.05201583, ...,  0.00457533,
#        -0.00929508, -0.04822817], dtype=float32)), (31, 'http://www.wikidata.org/entity/P1431', ['executive producer'], array([ 0.00746889, -0.04633453, -0.0374175 , ...,  0.02054253,
#         0.0094157 , -0.01533123], dtype=float32)), (32, 'http://www.wikidata.org/entity/P144', ['fork of', 'derived from', 'extended from', 'copy of', 'adapted from', 'based upon', 'theme', 'themed after', 'adaptation of', 'remake of', 'based on'], array([ 0.00746889, -0.10345223,  0.01574354, ..., -0.03578654,
#        -0.02553498, -0.02091421], dtype=float32)), (33, 'http://www.wikidata.org/entity/P1451', ['slogan', 'mission statement', 'mission', 'tagline', 'motto text'], array([ 0.00746889, -0.10449938,  0.0244074 , ..., -0.01660076,
#        -0.01616817, -0.02095892], dtype=float32)), (34, 'http://www.wikidata.org/entity/P1477', ['maiden name', 'born as', 'bn', 'bname', 'birth name (monolingual text)', 'name', 'birthname', 'name at birth', 'full name at birth', 'nee', 'real name', 'birth name'], array([ 0.00746889, -0.02811707,  0.01307602, ..., -0.00902223,
#        -0.01288703, -0.03169743], dtype=float32)), (35, 'http://www.wikidata.org/entity/P149', ['style of architecture', 'architecture', 'architectural style'], array([ 0.00746889, -0.09993166,  0.10164318, ..., -0.01649266,
#        -0.00918801, -0.00079385], dtype=float32)), (36, 'http://www.wikidata.org/entity/P150', ['contains', 'divides into', 'divided into', 'has towns', 'has shires', 'has cities', 'has rural cities', 'has municipalities', 'has wards', 'has local government areas', 'has districts', 'has boroughs', 'subdivided into', 'has counties', 'has administrative divisions', 'has arrondissements', 'has villages', 'has regions', 'contains administrative territorial entity'], array([ 0.00746889, -0.10830549, -0.02130332, ...,  0.01039621,
#        -0.0334546 , -0.0105994 ], dtype=float32)), (37, 'http://www.wikidata.org/entity/P155', ['succeeds to', 'previous is', 'before was', 'predecessor', 'preceded by', 'prequel is', 'sequel of', 'split from', 'followed', 'comes after', 'follows'], array([ 0.00746889, -0.08202343, -0.04085987, ..., -0.04779879,
#        -0.03197414, -0.01843197], dtype=float32)), (38, 'http://www.wikidata.org/entity/P156', ['succeded by', 'next is', 'precedes', 'sequel is', 'prequel of', 'successor', 'preceeds', 'followed by'], array([ 0.00746889, -0.07077838, -0.01557669, ..., -0.05068898,
#        -0.02579623, -0.01779506], dtype=float32)), (39, 'http://www.wikidata.org/entity/P159', ['head office location', 'HQ', 'garrison', 'admin HQ', 'seat', 'principle office', 'headquarters', 'head quarters', 'HQ location', 'headquarters location'], array([ 0.00746889, -0.09187677, -0.00761565, ..., -0.02767542,
#        -0.0261067 , -0.01383967], dtype=float32)), (40, 'http://www.wikidata.org/entity/P161', ['starring', 'film starring', 'actor', 'actress', 'contestant', 'cast member'], array([ 0.00746889, -0.09199479, -0.01167581, ..., -0.07401066,
#        -0.03245008, -0.01025101], dtype=float32)), (41, 'http://www.wikidata.org/entity/P1619', ['time of official opening', 'opening date', 'opened', 'date opened', 'officially opened on', 'inaugurated', 'launch date', 'introduced', 'introduction', 'official opening', 'date of official opening'], array([ 0.00746889, -0.08507169, -0.00433902, ..., -0.04797852,
#        -0.0475261 , -0.00717444], dtype=float32)), (42, 'http://www.wikidata.org/entity/P162', ['record producer', 'film producer', 'producer'], array([ 0.00746889, -0.09567472, -0.06039725, ..., -0.0102793 ,
#         0.0034788 , -0.01594857], dtype=float32)), (43, 'http://www.wikidata.org/entity/P17', ['sovereign state', 'state', 'land', 'country'], array([ 0.00746889, -0.08347838,  0.00314358, ..., -0.01419878,
#        -0.0448012 , -0.01749342], dtype=float32)), (44, 'http://www.wikidata.org/entity/P170', ['artist (non-musical)', 'created by', 'painter', 'sculptor', 'creators', 'painters', 'sculptors', 'made by', 'creator'], array([ 0.00746889, -0.060755  ,  0.07405219, ..., -0.04457568,
#        -0.01844842, -0.00682527], dtype=float32)), (45, 'http://www.wikidata.org/entity/P171', ['taxon parent', 'higher taxon', 'parent taxon'], array([ 0.00746889, -0.06128475, -0.01963148, ..., -0.08235862,
#        -0.06192419, -0.02307939], dtype=float32)), (46, 'http://www.wikidata.org/entity/P172', ['ethnicity', 'nationality', 'culture', 'peoples', 'ethnic group'], array([ 0.00746889, -0.05650676,  0.02059677, ..., -0.00867013,
#         0.01156505, -0.03743229], dtype=float32)), (47, 'http://www.wikidata.org/entity/P175', ['musical artist', 'artist', 'musician', 'played by', 'portrayed by', 'performer'], array([ 0.00746889, -0.0776636 ,  0.07201124, ..., -0.05820831,
#        -0.01405012, -0.0246606 ], dtype=float32)), (48, 'http://www.wikidata.org/entity/P176', ['manufactured by', 'maker', 'mfr', 'built by', 'builder', 'made by', 'producer (of product)', 'product of', 'manufacturer'], array([ 0.00746889, -0.05877689,  0.00449553, ..., -0.01444526,
#        -0.02634326,  0.00618618], dtype=float32)), (49, 'http://www.wikidata.org/entity/P177', ['bridge over', 'tunnel under', 'over', 'under', 'through', 'crosses'], array([ 0.00746889, -0.121871  ,  0.01533099, ..., -0.04790653,
#        -0.02484477, -0.01229053], dtype=float32)), (50, 'http://www.wikidata.org/entity/P178', ['developed by', 'developer'], array([ 0.00746889, -0.07690419,  0.03108859, ..., -0.02016054,
#         0.00286667, -0.02188784], dtype=float32)), (51, 'http://www.wikidata.org/entity/P179', ['part of series', 'part of the series'], array([ 7.4688899e-03, -1.0456637e-01, -1.1113700e-03, ...,
#        -3.5516497e-02, -3.5961188e-02, -9.5864641e-05], dtype=float32)), (52, 'http://www.wikidata.org/entity/P184', ['advisor', 'doctoral supervisor', 'supervisor', 'PhD advisor', 'doctoral advisor'], array([ 0.00746889, -0.11381163,  0.03966039, ..., -0.01805003,
#        -0.01831937, -0.03414972], dtype=float32)), (53, 'http://www.wikidata.org/entity/P189', ['findspot', 'location of discovered object', 'discovery place', 'place of discovery', 'discovered at:', 'location of discovery'], array([ 0.00746889, -0.09467888,  0.03925101, ..., -0.04991708,
#        -0.04148854, -0.01669712], dtype=float32)), (54, 'http://www.wikidata.org/entity/P19', ['birthplace', 'born in', 'POB', 'birth place', 'location born', 'born at', 'birth location', 'location of birth', 'birth city', 'place of birth'], array([ 0.00746889, -0.01930997,  0.02339626, ..., -0.02404313,
#        -0.02657312, -0.03164493], dtype=float32)), (55, 'http://www.wikidata.org/entity/P196', ['asteroid group', 'minor planet group'], array([ 0.00746889, -0.08610073,  0.01615429, ..., -0.06988347,
#        -0.0342306 ,  0.00387429], dtype=float32)), (56, 'http://www.wikidata.org/entity/P20', ['deathplace', 'died in', 'death place', 'POD', 'location of death', 'death location', 'place of death'], array([ 0.00746889, -0.09001659, -0.0378204 , ..., -0.06287862,
#        -0.04490203, -0.03310474], dtype=float32)), (57, 'http://www.wikidata.org/entity/P201', ['outflows', 'outflow', 'lake outflow'], array([ 0.00746889, -0.1184074 , -0.01794477, ..., -0.08980736,
#        -0.06475542,  0.03361703], dtype=float32)), (58, 'http://www.wikidata.org/entity/P2043', ['distance', 'dimension', 'size', 'long', 'length'], array([ 0.00746889, -0.09954387,  0.00480343, ..., -0.06210579,
#        -0.02833203, -0.01301314], dtype=float32)), (59, 'http://www.wikidata.org/entity/P2046', ['surface area', 'acreage', 'surface', 'size', 'total area', 'area'], array([ 0.00746889, -0.11344489, -0.02013192, ..., -0.05870606,
#        -0.04896717, -0.01971629], dtype=float32)), (60, 'http://www.wikidata.org/entity/P2048', ['depth over terrain', 'size', 'height'], array([ 0.00746889, -0.09773331,  0.0291578 , ..., -0.01622953,
#        -0.02557292,  0.01033014], dtype=float32)), (61, 'http://www.wikidata.org/entity/P21', ['gender identity', 'gender expression', 'gender', 'biological sex', 'man', 'woman', 'male', 'female', 'intersex', 'sex', 'sex or gender'], array([ 0.00746889, -0.0107792 , -0.02853255, ..., -0.06071726,
#        -0.01718169, -0.04083589], dtype=float32)), (62, 'http://www.wikidata.org/entity/P2130', ['unit cost', 'cost'], array([ 0.00746889, -0.09465875, -0.05220351, ..., -0.01860581,
#        -0.03456102, -0.01050231], dtype=float32)), (63, 'http://www.wikidata.org/entity/P2196', ['number of students', 'student count', 'count of students', 'enrollment', 'students count'], array([ 0.00746889, -0.12424877,  0.00655648, ..., -0.03533993,
#        -0.05543658, -0.00916746], dtype=float32)), (64, 'http://www.wikidata.org/entity/P22', ['dad', 'daddy', 'has father', 'parent', 'is son of', 'is daughter of', 'is child of', 'son of', 'daughter of', 'child of', 'father'], array([ 0.00746889,  0.04048086, -0.0109618 , ..., -0.03308188,
#        -0.04664158, -0.03136373], dtype=float32)), (65, 'http://www.wikidata.org/entity/P25', ['mum', 'mom', 'mam', 'has mother', 'parent', 'is son of', 'is daughter of', 'is child of', 'son of', 'daughter of', 'child of', 'mother'], array([ 0.00746889, -0.03346855, -0.01876701, ..., -0.03925255,
#        -0.04086696, -0.02963777], dtype=float32)), (66, 'http://www.wikidata.org/entity/P26', ['husband', 'wife', 'married to', 'consort', 'partner', 'marry', 'marriage partner', 'married', 'wedded to', 'wed', 'life partner', 'spouse'], array([ 0.00746889, -0.01543902,  0.06391454, ..., -0.05936284,
#        -0.03390509, -0.03482908], dtype=float32)), (67, 'http://www.wikidata.org/entity/P264', ['label', 'record label'], array([ 0.00746889, -0.10601339, -0.06921252, ..., -0.02622161,
#        -0.01574429, -0.02864224], dtype=float32)), (68, 'http://www.wikidata.org/entity/P27', ['citizenship', 'nationality', 'citizen of', 'national of', 'subject of (country)', 'country of citizenship'], array([ 0.00746889, -0.06430121,  0.01530017, ...,  0.01004987,
#        -0.01810502, -0.02732919], dtype=float32)), (69, 'http://www.wikidata.org/entity/P272', ['film studio', 'studio', 'motion picture studio', 'movie studio', 'production house', 'theatre company', 'theater company', 'theatrical troupe', 'ballet company', 'broadcasting company', 'production company'], array([ 0.00746889, -0.1090058 ,  0.02030014, ..., -0.04134914,
#        -0.01161814, -0.01356712], dtype=float32)), (70, 'http://www.wikidata.org/entity/P275', ['licence', 'content license', 'content licence', 'license'], array([ 0.00746889, -0.10471985,  0.06848736, ..., -0.01159918,
#        -0.01948962, -0.05370393], dtype=float32)), (71, 'http://www.wikidata.org/entity/P276', ['moveable object location', 'located in', 'event location', 'venue', 'is in', 'location of item', 'place held', 'based in', 'neighborhood', 'region', 'location'], array([ 0.00746889, -0.10612488,  0.00411006, ..., -0.06185686,
#        -0.03420629, -0.02278197], dtype=float32)), (72, 'http://www.wikidata.org/entity/P279', ['rdfs:subClassOf', 'hyponym of', 'has superclass', 'is also a', 'subtype of', 'is a subtype of', 'subcategory of', 'is a category of', 'is thereby also a', 'is necessarily also a', 'whose instances are among', 'whose instances are those of', 'subclass of'], array([ 0.00746889, -0.09489362, -0.00103573, ..., -0.02631658,
#        -0.04437238, -0.01332397], dtype=float32)), (73, 'http://www.wikidata.org/entity/P286', ['manager', 'club manager', 'senior coach', 'team manager', 'coach', 'coached by', 'head coach'], array([ 0.00746889, -0.12295233,  0.00291875, ...,  0.01217922,
#        -0.03073566, -0.04323285], dtype=float32)), (74, 'http://www.wikidata.org/entity/P287', ['has designer', 'designer', 'designed by'], array([ 0.00746889, -0.07828129,  0.03180908, ..., -0.03756708,
#         0.0018231 , -0.01830566], dtype=float32)), (75, 'http://www.wikidata.org/entity/P289', ['ship class', 'submarine class', 'spacecraft class', 'class of vessel', 'vessel class'], array([ 0.00746889, -0.08817574, -0.05495982, ..., -0.04128509,
#        -0.04842551, -0.01853842], dtype=float32)), (76, 'http://www.wikidata.org/entity/P31', ['is a', 'is an', 'has class', 'has type', 'is a particular', 'is a specific', 'is an individual', 'is a unique', 'is an example of', 'member of', 'unique individual of', 'distinct member of', 'non-type member of', 'unsubclassable example of', 'uninstantiable instance of', 'unsubclassifiable member of', 'not a type but is instance of', 'unsubtypable particular', 'unitary element of class', 'distinct element of', 'distinct individual member of', 'occurrence of', 'rdf:type', 'type', 'instance of', 'is a', 'is an', 'has class', 'has type', 'is a particular', 'is a specific', 'is an individual', 'is a unique', 'is an example of', 'member of', 'unique individual of', 'distinct member of', 'non-type member of', 'unsubclassable example of', 'uninstantiable instance of', 'unsubclassifiable member of', 'not a type but is instance of', 'unsubtypable particular', 'unitary element of class', 'distinct element of', 'distinct individual member of', 'occurrence of', 'rdf:type', 'type', 'instance of'], array([ 0.00746889, -0.10151681,  0.00212692, ..., -0.02448319,
#        -0.04749737, -0.01547655], dtype=float32)), (77, 'http://www.wikidata.org/entity/P344', ['cinematographer', 'DOP', 'director of photography'], array([ 0.00746889, -0.01745754,  0.07742625, ..., -0.03224602,
#        -0.02825398, -0.03121058], dtype=float32)), (78, 'http://www.wikidata.org/entity/P36', ['capital city', 'capital town', 'chef-lieu', 'principal place', 'county seat', 'administrative centre', 'administrative headquarters', 'capital'], array([ 0.00746889, -0.12022485, -0.01473773, ..., -0.03171764,
#        -0.04151522,  0.00369991], dtype=float32)), (79, 'http://www.wikidata.org/entity/P361', ['meronym of', 'section of', 'system of', 'subsystem of', 'subassembly of', 'merged into', 'contained within', 'assembly of', 'part of-property', 'merged with', 'component of', 'in', 'within', 'part of'], array([ 0.00746889, -0.10833788,  0.010845  , ..., -0.04871992,
#        -0.04551169, -0.00840333], dtype=float32)), (80, 'http://www.wikidata.org/entity/P364', ['original language', 'language of the original work', 'created on language', 'original language of film or TV show'], array([ 0.00746889, -0.04833895,  0.05356934, ..., -0.0281768 ,
#         0.00561129, -0.00910143], dtype=float32)), (81, 'http://www.wikidata.org/entity/P376', ['planet', 'astronomical body (location)', 'on astronomical body'], array([ 0.00746889, -0.05372881,  0.01455377, ..., -0.05911385,
#        -0.02554132,  0.00890275], dtype=float32)), (82, 'http://www.wikidata.org/entity/P397', ['parent body', 'orbits', 'star', 'planetary system', 'parent astronomical body'], array([ 0.00746889, -0.06552197,  0.01394539, ..., -0.06235822,
#        -0.04485999,  0.00201396], dtype=float32)), (83, 'http://www.wikidata.org/entity/P398', ['child body', 'satellite', 'orbited by', 'has planet', 'has moon', 'child astronomical body'], array([ 0.00746889, -0.08117469,  0.01556168, ..., -0.03923402,
#        -0.0329527 ,  0.00505446], dtype=float32)), (84, 'http://www.wikidata.org/entity/P40', ['son', 'daughter', 'kid', 'has child', 'children', 'sons', 'daughters', 'kids', 'has children', 'has son', 'has sons', 'has daughter', 'has daughters', 'has kid', 'has kids', 'parent of', 'child'], array([ 0.00746889, -0.01930528, -0.02803884, ..., -0.01705814,
#        -0.04769382, -0.03648052], dtype=float32)), (85, 'http://www.wikidata.org/entity/P403', ['watercourse outflow', 'watercourse drain', 'tributary of', 'outflow', 'drain', 'river mouth', 'outlet', 'confluences', 'watercourse ends in', 'mouth of the watercourse'], array([ 0.00746889, -0.10943554,  0.01659429, ..., -0.06757563,
#        -0.04378536, -0.00860567], dtype=float32)), (86, 'http://www.wikidata.org/entity/P404', ['mode', 'gameplay', 'game mode'], array([ 0.00746889, -0.09820456, -0.04176806, ..., -0.06294233,
#        -0.05383183, -0.04310402], dtype=float32)), (87, 'http://www.wikidata.org/entity/P407', ['language of the name', 'language of name', 'named in language', 'broadcasting language', 'audio language', 'available in', 'language of work', 'language of the reference', 'language of work or name'], array([ 0.00746889, -0.09457623,  0.0291924 , ..., -0.02507537,
#        -0.01385907, -0.0176533 ], dtype=float32)), (88, 'http://www.wikidata.org/entity/P413', ['player position', 'fielding position', 'specialism', 'position (on team)', 'speciality', 'position played on team / speciality'], array([ 0.00746889, -0.08159697,  0.03214568, ..., -0.01133625,
#        -0.05125558, -0.03418026], dtype=float32)), (89, 'http://www.wikidata.org/entity/P421', ['timezone', 'tz', 'time zone', 'time', 'located in time zone'], array([ 0.00746889, -0.06004321, -0.05043457, ...,  0.02023556,
#        -0.04693506, -0.00919832], dtype=float32)), (90, 'http://www.wikidata.org/entity/P452', ['field of action', 'field of exercise', 'sector', 'branch', 'economic branch', 'industry'], array([ 0.00746889, -0.11876743,  0.00349247, ..., -0.04196915,
#        -0.04975629, -0.03026739], dtype=float32)), (91, 'http://www.wikidata.org/entity/P466', ['occupied by', 'tenant', 'inhabitant', 'inhabited by', 'occupant'], array([ 0.00746889, -0.09014051, -0.01580956, ..., -0.06179535,
#        -0.01865068, -0.03537717], dtype=float32)), (92, 'http://www.wikidata.org/entity/P488', ['chairman', 'chairwoman', 'leader', 'headed by', 'president', 'chairperson'], array([ 0.00746889, -0.09487313, -0.00211038, ..., -0.03418916,
#        -0.03051691, -0.03551855], dtype=float32)), (93, 'http://www.wikidata.org/entity/P495', ['place of origin', 'comes from', 'origin (country)', 'originates', 'CoO', 'country of origin'], array([ 0.00746889, -0.0672641 ,  0.00579072, ..., -0.00508729,
#        -0.02668478, -0.01347279], dtype=float32)), (94, 'http://www.wikidata.org/entity/P50', ['written by', 'writer', 'writers', 'authors', 'author(s)', 'writer(s)', 'author'], array([ 0.00746889, -0.08519266, -0.00561788, ..., -0.00898431,
#         0.00924559, -0.0180424 ], dtype=float32)), (95, 'http://www.wikidata.org/entity/P509', ['death cause', 'die from', 'murder method', 'method of murder', 'cause of death'], array([ 0.00746889, -0.08087448, -0.00289316, ..., -0.03800194,
#        -0.02910612, -0.02600964], dtype=float32)), (96, 'http://www.wikidata.org/entity/P53', ['royal house', 'dynasty', 'house', 'noble family', 'family'], array([ 0.00746889, -0.08968775,  0.05547171, ..., -0.02782292,
#        -0.0267676 , -0.05228692], dtype=float32)), (97, 'http://www.wikidata.org/entity/P569', ['born on', 'birth date', 'birthdate', 'birth year', 'year of birth', 'birthyear', 'DOB', 'birthday', 'date of birth'], array([ 0.00746889, -0.00334357,  0.02261555, ..., -0.00888429,
#        -0.03622377, -0.01718537], dtype=float32)), (98, 'http://www.wikidata.org/entity/P57', ['directed by', 'film director', 'movie director', 'director'], array([ 0.00746889, -0.0775247 , -0.01932754, ..., -0.03635337,
#        -0.0026705 , -0.02463046], dtype=float32)), (99, 'http://www.wikidata.org/entity/P570', ['date of the end', 'death date', 'died on', 'DOD', 'year of death', 'dead', 'deathdate', 'death', 'date of death'], array([ 0.00746889, -0.08889773, -0.04126688, ..., -0.05447251,
#        -0.05123369, -0.01458549], dtype=float32)), (100, 'http://www.wikidata.org/entity/P571', ['date founded', 'date created', 'incorporated', 'foundation', 'founded', 'created', 'date of foundation', 'date of creation', 'established', 'establishment date', 'foundation date', 'creation date', 'incorporation date', 'date incorporated', 'date of incorporation', 'date of establishment', 'founding date', 'date of founding', 'date formed', 'formation date', 'formed on date', 'founded on date', 'incorporated on date', 'established on date', 'created on date', 'commencement date', 'date commenced', 'commenced on date', 'date of commencement', 'foundation/creation date', 'time of foundation or creation', 'date of foundation or creation', 'written on date', 'time of inception', 'year founded', 'year created', 'year incorporated', 'year written', 'year commenced', 'year established', 'date constructed', 'construction date', 'constructed', 'inititated', 'formation', 'dedication date', 'formed in', 'formed at', 'inaugurated', 'launch date', 'introduced', 'introduction', 'start date', 'completed', 'first issue', 'inception'], array([ 0.00746889, -0.08429937,  0.01679092, ..., -0.03570899,
#        -0.04545629,  0.00372993], dtype=float32)), (101, 'http://www.wikidata.org/entity/P58', ['scriptwriter', 'screenplay by', 'teleplay by', 'writer (of screenplays)', 'film script by', 'screenwriter'], array([ 0.00746889, -0.07585476, -0.02054208, ..., -0.06021911,
#         0.03894403, -0.02066674], dtype=float32)), (102, 'http://www.wikidata.org/entity/P59', ['part of constellation', 'constellation'], array([ 0.00746889, -0.12448856,  0.04086464, ..., -0.05161938,
#        -0.05475156,  0.0334425 ], dtype=float32)), (103, 'http://www.wikidata.org/entity/P6', ['mayor', 'prime minister', 'premier', 'first minister', 'head of national government', 'chancellor', 'governor', 'government headed by', 'executive power headed by', 'president', 'head of government'], array([ 0.00746889, -0.07440884,  0.00678919, ...,  0.00227248,
#        -0.01890069, -0.01602917], dtype=float32)), (104, 'http://www.wikidata.org/entity/P607', ['war', 'battle', 'participated in conflict', 'participant in conflict', 'in conflict', 'in action', 'theater (military)', 'theatre (military)', 'conflict'], array([ 0.00746889, -0.08776493, -0.0140864 , ..., -0.04892388,
#        -0.04365614, -0.00997769], dtype=float32)), (105, 'http://www.wikidata.org/entity/P61', ['inventor', 'discovered by', 'invented by', 'discoverer', 'coined by', 'first described by', 'inventor or discoverer', 'invented or discovered by', 'discovered or invented by', 'developer', 'developed by', 'discoverer or inventor'], array([ 0.00746889, -0.02059271,  0.04111049, ..., -0.01535775,
#         0.00664134, -0.01525358], dtype=float32)), (106, 'http://www.wikidata.org/entity/P641', ['sports', 'sport played', 'sport'], array([ 0.00746889, -0.11141273,  0.0349226 , ..., -0.03551095,
#        -0.06395694, -0.05034419], dtype=float32)), (107, 'http://www.wikidata.org/entity/P65', ['discovery site', 'site of astronomical discovery'], array([ 0.00746889, -0.06918618,  0.08389997, ..., -0.04532529,
#        -0.04476157,  0.0233233 ], dtype=float32)), (108, 'http://www.wikidata.org/entity/P676', ['lyricist', 'lyracist', 'words by', 'writer (of song lyrics)', 'author', 'lyrics by'], array([ 0.00746889, -0.09283764,  0.02717627, ..., -0.0484614 ,
#         0.01360821, -0.02913518], dtype=float32)), (109, 'http://www.wikidata.org/entity/P69', ['education', 'alumni of', 'alumnus of', 'alumna of', 'college attended', 'university attended', 'school attended', 'studied at', 'alma mater', 'graduate of', 'graduated from', 'faculty', 'educated at'], array([ 0.00746889, -0.11812532,  0.03232218, ...,  0.0037202 ,
#        -0.02412255, -0.03048944], dtype=float32)), (110, 'http://www.wikidata.org/entity/P710', ['participants', 'attendee', 'player', 'competitor', 'candidate', 'party', 'event participant', 'agent', 'belligerents', 'between', 'victim', 'perpetrator', 'suspect', 'accused', 'participant'], array([ 0.00746889, -0.08898111, -0.03927629, ..., -0.04155045,
#        -0.04045466, -0.03456549], dtype=float32)), (111, 'http://www.wikidata.org/entity/P737', ['informed by', 'has influence', 'influenced by'], array([ 0.00746889, -0.08530015, -0.01146756, ..., -0.02576495,
#         0.01431803, -0.02396838], dtype=float32)), (112, 'http://www.wikidata.org/entity/P800', ['literary works', 'bibliography', 'work', 'works', 'major works', 'famous works', 'significant works', 'known for', 'notable books', 'famous books', 'famous for', 'significance', 'representative work', 'artwork', 'notable work'], array([ 0.00746889, -0.11120386,  0.08975589, ..., -0.02465496,
#        -0.01470058, -0.01274516], dtype=float32)), (113, 'http://www.wikidata.org/entity/P81', ['railway line', 'rapid transit line', 'line connected to', 'rail line connected to', 'is on', 'connecting line'], array([ 0.00746889, -0.00994754,  0.02720047, ..., -0.05823435,
#         0.00154917, -0.01462658], dtype=float32)), (114, 'http://www.wikidata.org/entity/P822', ['mascot'], array([ 0.00746889, -0.11935683,  0.01861135, ..., -0.06835024,
#        -0.06215507, -0.01624648], dtype=float32)), (115, 'http://www.wikidata.org/entity/P826', ['musical key', 'key of musical composition', 'tonality'], array([ 0.00746889, -0.09504185,  0.13487108, ..., -0.03815362,
#        -0.04354132, -0.02586152], dtype=float32)), (116, 'http://www.wikidata.org/entity/P84', ['architecture firm', 'architect'], array([ 0.00746889, -0.05023341,  0.05325206, ...,  0.00557685,
#         0.00211892, -0.0081402 ], dtype=float32)), (117, 'http://www.wikidata.org/entity/P86', ['songwriter', 'composed by', 'musical score by', 'music by', 'written by', 'composer'], array([ 0.00746889, -0.0791524 ,  0.1004898 , ..., -0.04683314,
#         0.02037168, -0.01148337], dtype=float32)), (118, 'http://www.wikidata.org/entity/P885', ['river source', 'stream source', 'source of a stream', 'water source', 'water origin', 'river head', 'source of watercourse', 'origin of a watercourse'], array([ 0.00746889, -0.10458165,  0.02325128, ..., -0.04159704,
#        -0.03629654, -0.02194456], dtype=float32)), (119, 'http://www.wikidata.org/entity/P969', ['address', 'street address', 'street without article', 'physical address', 'located at street address'], array([ 0.00746889, -0.06301325, -0.01105576, ..., -0.03168726,
#         0.03481667, -0.03933041], dtype=float32)), (120, 'http://www.wikidata.org/entity/P1001', ['applies to jurisdiction', 'of jurisdiction', 'linked to jurisdiction', 'belongs to jurisdiction', 'jurisdiction', 'country of jurisdiction', 'valid in jurisdiction', 'applies to territorial jurisdiction', 'applied to jurisdiction'], array([ 0.00746889, -0.03260348,  0.02242357, ...,  0.00092162,
#        -0.05534602, -0.03559341], dtype=float32)), (121, 'http://www.wikidata.org/entity/P102', ['member of political party', 'political party', 'party', 'member of', 'member of party', 'party membership'], array([ 0.00746889, -0.10757729, -0.02620746, ..., -0.01318687,
#        -0.0330568 , -0.03491578], dtype=float32)), (122, 'http://www.wikidata.org/entity/P1027', ['conferred by', 'awarded by', 'bestowed by', 'given by', 'granted by', 'presented by'], array([ 0.00746889, -0.07733814,  0.0815266 , ..., -0.03303924,
#         0.00246411, -0.01557483], dtype=float32)), (123, 'http://www.wikidata.org/entity/P1028', ['donated by', 'given by', 'bestowed by', 'gift from', 'donation from'], array([ 0.00746889, -0.08397834,  0.1150314 , ...,  0.00134286,
#        -0.00378135, -0.01242692], dtype=float32)), (124, 'http://www.wikidata.org/entity/P103', ['native language', 'first language', 'mother tongue', 'language native', 'L1 speaker of'], array([ 0.00746889, -0.09836838,  0.016137  , ..., -0.03667082,
#        -0.01578017, -0.01731042], dtype=float32)), (125, 'http://www.wikidata.org/entity/P1037', ['manager/director', 'art director', 'manager', 'director'], array([ 0.00746889, -0.10312655,  0.01439906, ..., -0.03770284,
#        -0.02875092, -0.03395334], dtype=float32)), (126, 'http://www.wikidata.org/entity/P1038', ['relative', 'family', 'family member', 'kinsman', 'relation'], array([ 0.00746889, -0.06040001,  0.00583392, ..., -0.03429636,
#        -0.0472539 , -0.04928674], dtype=float32)), (127, 'http://www.wikidata.org/entity/P1050', ['medical condition', 'disability', 'ailment', 'health problem', 'disorder', 'illness', 'disease', 'paralympic disability', 'health condition'], array([ 0.00746889, -0.10996383, -0.04257701, ..., -0.06335653,
#        -0.03932592, -0.04272054], dtype=float32)), (128, 'http://www.wikidata.org/entity/P1056', ['product or material produced', 'material produced', 'produces', 'manufactures', 'makes', 'has product', 'product', 'maker of', 'manufacturer of', 'producer of', 'results in', 'creates', 'output', 'products', 'work produced', 'commodity'], array([ 0.00746889, -0.10277254, -0.01976692, ..., -0.03544769,
#        -0.05267674, -0.01607729], dtype=float32)), (129, 'http://www.wikidata.org/entity/P1057', ['chromosome', 'on chromosome'], array([ 0.00746889, -0.11930386, -0.06072804, ..., -0.08991538,
#        -0.05735777, -0.03296139], dtype=float32)), (130, 'http://www.wikidata.org/entity/P1064', ['track gauge', 'gauge'], array([ 0.00746889, -0.13236079, -0.06872479, ..., -0.09991686,
#        -0.05536786, -0.0470889 ], dtype=float32)), (131, 'http://www.wikidata.org/entity/P1066', ['student of', 'teacher', 'professor', 'pupil of', 'supervisor', 'academic supervisor', 'disciple of', 'studied under', 'master', 'mentor', 'advisor', 'tutor'], array([ 0.00746889, -0.09434333,  0.02144702, ..., -0.02409578,
#        -0.04049577, -0.03376247], dtype=float32)), (132, 'http://www.wikidata.org/entity/P1071', ['location of final assembly', 'assembly location', 'place built', 'place made', 'location of origin', 'place of origin', 'made in', 'minted at', 'mint'], array([ 0.00746889, -0.0890751 , -0.01778769, ..., -0.05175283,
#        -0.03755915, -0.00061748], dtype=float32)), (133, 'http://www.wikidata.org/entity/P108', ['employer', 'workplace', 'employed by', 'works at', 'working for', 'worked for', 'works for', 'worked at'], array([ 0.00746889, -0.10461523,  0.02955575, ..., -0.03709388,
#        -0.04351095, -0.03233599], dtype=float32)), (134, 'http://www.wikidata.org/entity/P1080', ['from fictional universe', 'from universe', 'universe', 'featured in universe', 'appears in universe', 'fictional universe where entity is from', 'from mythology', 'mythology', 'continuity', 'in continuity', 'cycle', 'in cycle', 'in world of', 'story cycle', 'from narrative'], array([ 0.00746889, -0.10815045,  0.00315523, ..., -0.04986321,
#        -0.01679868, -0.0283492 ], dtype=float32)), (135, 'http://www.wikidata.org/entity/P110', ['illustrator', 'illustration by', 'illustrated by'], array([ 0.00746889, -0.08143417,  0.02212553, ..., -0.07437987,
#         0.00338603, -0.02244877], dtype=float32)), (136, 'http://www.wikidata.org/entity/P118', ['league', 'division', 'sports league'], array([ 0.00746889, -0.10322019, -0.03534901, ...,  0.03443328,
#        -0.01189877, -0.03110619], dtype=float32)), (137, 'http://www.wikidata.org/entity/P1192', ['connecting service'], array([ 0.00746889, -0.10161031,  0.13248658, ..., -0.02284921,
#        -0.00663287, -0.06184948], dtype=float32)), (138, 'http://www.wikidata.org/entity/P1196', ['manner of death', 'circumstance of death', 'type of death', 'death manner', 'death type'], array([ 0.00746889, -0.07776888, -0.0237633 , ..., -0.06013709,
#        -0.05832132, -0.02939128], dtype=float32)), (139, 'http://www.wikidata.org/entity/P121', ['item operated', 'fleet', 'aircraft in fleet', 'aircraft operated', 'equipment operated', 'facility operated', 'service operated', 'operator of', 'operated', 'operates', 'eq', 'acop', 'aircraft carried', 'item used', 'uses item'], array([ 0.00746889, -0.0907164 ,  0.00348662, ..., -0.04998358,
#        -0.05531274, -0.03142532], dtype=float32)), (140, 'http://www.wikidata.org/entity/P126', ['maintained by', 'maintenance', 'administered by', 'maintainer', 'custodian', 'administrator'], array([ 0.00746889, -0.1129126 , -0.02444499, ..., -0.08097877,
#        -0.04059677, -0.03205316], dtype=float32)), (141, 'http://www.wikidata.org/entity/P129', ['physically interacts with'], array([ 0.00746889, -0.10965479, -0.00160275, ..., -0.07117449,
#        -0.05297119, -0.03656542], dtype=float32)), (142, 'http://www.wikidata.org/entity/P1340', ['eye color', 'eye colour', 'eyecolor', 'eyecolour'], array([ 0.00746889, -0.09070608,  0.01561232, ..., -0.08260216,
#        -0.03315877, -0.04063826], dtype=float32)), (143, 'http://www.wikidata.org/entity/P1344', ['participant of', 'took part', 'took part in', 'participant in', 'participated in', 'competed in', 'participant of event'], array([ 0.00746889, -0.11156987, -0.01358857, ..., -0.03467052,
#        -0.0607294 , -0.02431748], dtype=float32)), (144, 'http://www.wikidata.org/entity/P1346', ['winner', 'won by', 'victor', 'champion', 'winners'], array([ 0.00746889, -0.08479425,  0.04694447, ..., -0.05581521,
#        -0.00556481, -0.03128774], dtype=float32)), (145, 'http://www.wikidata.org/entity/P1376', ['capital of', 'county seat of', 'county seat for'], array([ 0.00746889, -0.12642509,  0.00928318, ..., -0.01805618,
#        -0.05462859, -0.01627286], dtype=float32)), (146, 'http://www.wikidata.org/entity/P1382', ['partially coincident with', 'partially overlaps', 'partial concurrency', 'concurrent with', 'concurrency', 'overlapping with', 'partially include', 'partially in', 'coincident with'], array([ 0.00746889, -0.12647957, -0.02640726, ..., -0.08261435,
#        -0.0557429 , -0.03745903], dtype=float32)), (147, 'http://www.wikidata.org/entity/P1383', ['contains settlement', 'populated places within'], array([ 0.00746889, -0.1303378 ,  0.01962653, ..., -0.01858419,
#        -0.03572604,  0.00137005], dtype=float32)), (148, 'http://www.wikidata.org/entity/P1389', ['product certification'], array([ 0.00746889, -0.07461821, -0.00421137, ..., -0.01887558,
#        -0.04302675, -0.00918528], dtype=float32)), (149, 'http://www.wikidata.org/entity/P1399', ['convicted of', 'guilty of', 'found guilty of'], array([ 0.00746889, -0.08823177, -0.02731123, ..., -0.0189208 ,
#        -0.04911916, -0.02411097], dtype=float32)), (150, 'http://www.wikidata.org/entity/P1403', ['original combination', 'protonym'], array([ 0.00746889, -0.08646245,  0.00068759, ..., -0.08359145,
#        -0.04613895, -0.01797431], dtype=float32)), (151, 'http://www.wikidata.org/entity/P1411', ['nominated for', 'nominee for', 'nomination received'], array([ 0.00746889, -0.11364005,  0.05295813, ..., -0.05307858,
#        -0.04170178, -0.02836934], dtype=float32)), (152, 'http://www.wikidata.org/entity/P1427', ['start point', 'flight origin', 'start location', 'from', 'journey start', 'journey origin', 'launch location', 'launch site', 'launch pad'], array([ 0.00746889, -0.09666979, -0.03182364, ..., -0.04155178,
#        -0.02183265, -0.0194308 ], dtype=float32)), (153, 'http://www.wikidata.org/entity/P1433', ['published in', 'on the tracklist of', 'venue', 'part of work', 'published in journal'], array([ 0.00746889, -0.10744937,  0.00383477, ..., -0.04640889,
#        -0.02464196, -0.0108427 ], dtype=float32)), (154, 'http://www.wikidata.org/entity/P1434', ['takes place in fictional universe', 'describes fictional universe', 'fictional universe described', 'universe described', 'universe featured', 'set in fictional universe', 'describes the fictional universe', 'continuity'], array([ 0.00746889, -0.08633321,  0.04550989, ..., -0.05630203,
#         0.00648443, -0.01934438], dtype=float32)), (155, 'http://www.wikidata.org/entity/P1435', ['heritage designation', 'designation', 'listing', 'listed status', 'protected status', 'protection', 'legal protection', 'heritage designation', 'heritage status'], array([ 0.00746889, -0.11637208,  0.04805945, ..., -0.02481712,
#        -0.05292242, -0.02769838], dtype=float32)), (156, 'http://www.wikidata.org/entity/P1441', ['present in work', 'from work', 'from narrative', 'featured in work', 'in work', 'in narrative', 'appears in', 'is shown in'], array([ 0.00746889, -0.1083998 ,  0.01063263, ..., -0.04008168,
#        -0.03712685, -0.02519446], dtype=float32)), (157, 'http://www.wikidata.org/entity/P1444', ['destination point', 'destination', 'to', 'end of journey', 'finish', 'journey destination', 'ending at', 'stopping at', 'end point (journey)'], array([ 0.00746889, -0.08768722, -0.02017696, ..., -0.03575685,
#        -0.03295397, -0.01508649], dtype=float32)), (158, 'http://www.wikidata.org/entity/P1445', ['fictional universe described in'], array([ 0.00746889, -0.07687385,  0.04050624, ..., -0.06661631,
#         0.02868541, -0.02230076], dtype=float32)), (159, 'http://www.wikidata.org/entity/P1454', ['legal form', 'type of business entity'], array([ 0.00746889, -0.09502095,  0.01350176, ..., -0.02222276,
#        -0.03096005, -0.01520401], dtype=float32)), (160, 'http://www.wikidata.org/entity/P1462', ['standards body', 'standards organisation', 'standards setting organization', 'standards setting organisation', 'standards developing organization', 'standards developing organisation'], array([ 0.00746889, -0.14137582, -0.00020943, ...,  0.01984984,
#        -0.03410399, -0.0268397 ], dtype=float32)), (161, 'http://www.wikidata.org/entity/P1532', ['country for sport', 'sporting nationality', 'sports nationality', 'sport nationality', 'sport country', 'sports country'], array([ 0.00746889, -0.04879841,  0.03682607, ...,  0.02383462,
#        -0.00033199, -0.03334726], dtype=float32)), (162, 'http://www.wikidata.org/entity/P1533', ['family name identical to this given name', 'related surname', 'related family name', 'family name identical to this first name'], array([ 0.00746889, -0.07322878,  0.02180499, ..., -0.02768376,
#        -0.02746074, -0.01393643], dtype=float32)), (163, 'http://www.wikidata.org/entity/P1542', ['has effect', 'effect', 'has result', 'result', 'has outcome', 'outcome', 'has symptom', 'consequence', 'causes', 'implies', 'cause of'], array([ 0.00746889, -0.10930279, -0.06563281, ..., -0.03670165,
#        -0.06207621, -0.02199239], dtype=float32)), (164, 'http://www.wikidata.org/entity/P157', ['killed by', 'killer', 'assassin', 'murderer', 'murdered by', 'executioner', 'assassinated by', 'slain by', 'mortally wounded by', 'executed by', 'slaughtered by'], array([ 0.00746889, -0.09383232, -0.0337444 , ..., -0.07959021,
#         0.00909625, -0.02715185], dtype=float32)), (165, 'http://www.wikidata.org/entity/P1576', ['lifestyle'], array([ 0.00746889, -0.11606379, -0.02755552, ..., -0.04127587,
#        -0.00422851, -0.06864641], dtype=float32)), (166, 'http://www.wikidata.org/entity/P16', ['highway system', 'network of routes', 'system of routes', 'transport network', 'routes system', 'part of network', 'road type'], array([ 0.00746889, -0.10967068,  0.01560763, ..., -0.03998447,
#        -0.01879335,  0.00089532], dtype=float32)), (167, 'http://www.wikidata.org/entity/P163', ['flag', 'flag description'], array([ 0.00746889, -0.11496017, -0.00205813, ..., -0.03054126,
#        -0.05833792, -0.02542537], dtype=float32)), (168, 'http://www.wikidata.org/entity/P166', ['award received', 'prize received', 'awards', 'honorary title', 'recognition title', 'award', 'honours', 'honors', 'medals', 'awarded', 'award won', 'prize awarded', 'awards received', 'win', 'winner of'], array([ 0.00746889, -0.1135734 ,  0.07270671, ..., -0.04089643,
# ...
#        -0.0404624 , -0.04344497], dtype=float32)), (251, 'http://www.wikidata.org/entity/P516', ['powerplant', 'engine', 'power plant', 'turbine', 'rocket engine', 'reactor', 'propulsion', 'power station', 'powerstation', 'prime mover'], array([ 0.00746889, -0.10022239, -0.01780172, ..., -0.06110171,
#        -0.04597189, -0.02072648], dtype=float32)), (252, 'http://www.wikidata.org/entity/P520', ['armament', 'armed with', 'weapon', 'ship armament'], array([ 0.00746889, -0.08795095, -0.04994107, ..., -0.07584888,
#        -0.05278282, -0.03188845], dtype=float32)), (253, 'http://www.wikidata.org/entity/P530', ['diplomatic relation'], array([ 0.00746889, -0.04369181, -0.03184959, ..., -0.05833476,
#        -0.0611693 , -0.02256042], dtype=float32)), (254, 'http://www.wikidata.org/entity/P532', ['port of registry'], array([ 0.00746889, -0.09217001, -0.02884354, ..., -0.02040952,
#        -0.0240328 , -0.02399391], dtype=float32)), (255, 'http://www.wikidata.org/entity/P54', ['member of sports team', 'member of team', 'team', 'team played for', 'played for', 'plays for', 'teams played for', 'of team', 'club played for', 'player of', 'part of team'], array([ 0.00746889, -0.09588297,  0.00084733, ..., -0.01207617,
#        -0.05758943, -0.03261099], dtype=float32)), (256, 'http://www.wikidata.org/entity/P551', ['residence', 'lived in', 'resident in', 'lives in', 'hometown', 'home town', 'place of residence'], array([ 0.00746889, -0.09738101, -0.01435576, ..., -0.03527829,
#        -0.02819133, -0.04049257], dtype=float32)), (257, 'http://www.wikidata.org/entity/P559', ['terminus', 'termini', 'end point', 'terminating connection'], array([ 0.00746889, -0.10604287, -0.03590193, ..., -0.07822043,
#        -0.04401397, -0.03771159], dtype=float32)), (258, 'http://www.wikidata.org/entity/P560', ['direction', 'facing'], array([ 0.00746889, -0.11806804, -0.05738187, ..., -0.08159873,
#        -0.04819894, -0.03831089], dtype=float32)), (259, 'http://www.wikidata.org/entity/P566', ['basionym'], array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#        -0.06125114, -0.04683771], dtype=float32)), (260, 'http://www.wikidata.org/entity/P608', ['exhibition history'], array([ 0.00746889, -0.12569919,  0.04942005, ...,  0.01047989,
#        -0.00977623, -0.00563311], dtype=float32)), (261, 'http://www.wikidata.org/entity/P609', ['terminus location', 'destination', 'departure point', 'from', 'to', 'between'], array([ 0.00746889, -0.08883855, -0.01782761, ..., -0.05712854,
#        -0.0298274 , -0.0238302 ], dtype=float32)), (262, 'http://www.wikidata.org/entity/P610', ['highest point', 'highest peak', 'zenith', 'summit', 'extreme point highest'], array([ 0.00746889, -0.07806122,  0.04839835, ..., -0.0154065 ,
#        -0.03630566,  0.02401295], dtype=float32)), (263, 'http://www.wikidata.org/entity/P611', ['religious order', 'order'], array([ 0.00746889, -0.04391029,  0.02865179, ..., -0.04125577,
#         0.00182869, -0.02075358], dtype=float32)), (264, 'http://www.wikidata.org/entity/P629', ['edition or translation of', 'edition of', 'translation of'], array([ 0.00746889, -0.09239893, -0.00964895, ..., -0.03408875,
#        -0.0014395 , -0.01216516], dtype=float32)), (265, 'http://www.wikidata.org/entity/P636', ['route of administration'], array([ 0.00746889, -0.1136563 ,  0.03030581, ...,  0.00268124,
#        -0.06475541,  0.00628042], dtype=float32)), (266, 'http://www.wikidata.org/entity/P647', ['drafted by'], array([ 0.00746889, -0.08315081, -0.01273686, ...,  0.02463687,
#         0.02148831, -0.0126447 ], dtype=float32)), (267, 'http://www.wikidata.org/entity/P655', ['translator', 'translated by'], array([ 0.00746889, -0.09867227,  0.02827215, ..., -0.02313377,
#         0.04317325, -0.01159896], dtype=float32)), (268, 'http://www.wikidata.org/entity/P658', ['tracklist', 'track list', 'track listing', 'list of tracks', 'songs'], array([ 7.4688881e-03, -1.3161966e-01,  5.2276253e-05, ...,
#        -5.7251044e-02, -2.5336534e-02, -3.7943643e-02], dtype=float32)), (269, 'http://www.wikidata.org/entity/P664', ['organizer', 'organiser', 'event producer'], array([ 0.00746889, -0.1292169 , -0.05246483, ..., -0.07310779,
#        -0.04663146, -0.03654133], dtype=float32)), (270, 'http://www.wikidata.org/entity/P669', ['located on street', 'is on', 'street', 'square', 'road', 'address street', 'on street'], array([ 0.00746889, -0.10602216, -0.02114947, ..., -0.05959889,
#         0.00237435, -0.02746429], dtype=float32)), (271, 'http://www.wikidata.org/entity/P674', ['characters'], array([ 0.00746889, -0.13863035, -0.06401081, ..., -0.09271191,
#        -0.04852505, -0.03852709], dtype=float32)), (272, 'http://www.wikidata.org/entity/P680', ['molecular function'], array([ 0.00746889, -0.06667592,  0.00768205, ..., -0.0814857 ,
#        -0.06475541, -0.03094646], dtype=float32)), (273, 'http://www.wikidata.org/entity/P681', ['cell component', 'subcellular localization'], array([ 0.00746889, -0.12272236, -0.03405198, ..., -0.09359629,
#        -0.04658266, -0.02795182], dtype=float32)), (274, 'http://www.wikidata.org/entity/P682', ['biological process'], array([ 0.00746889,  0.03187265, -0.0206883 , ..., -0.07618638,
#        -0.03293724, -0.01944356], dtype=float32)), (275, 'http://www.wikidata.org/entity/P684', ['ortholog'], array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#        -0.06125114, -0.04683771], dtype=float32)), (276, 'http://www.wikidata.org/entity/P688', ['encodes', 'codes for'], array([ 0.00746889, -0.12207395, -0.02049602, ..., -0.06881712,
#        -0.01876467, -0.03364338], dtype=float32)), (277, 'http://www.wikidata.org/entity/P689', ['afflicts'], array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#        -0.06125114, -0.04683771], dtype=float32)), (278, 'http://www.wikidata.org/entity/P702', ['encoded by'], array([ 0.00746889, -0.07695843, -0.00368243, ..., -0.0890227 ,
#         0.00246412, -0.02083005], dtype=float32)), (279, 'http://www.wikidata.org/entity/P703', ['found in taxon', 'species'], array([ 0.00746889, -0.13343476,  0.01732828, ..., -0.09126101,
#        -0.06393128, -0.01951968], dtype=float32)), (280, 'http://www.wikidata.org/entity/P706', ['located on terrain feature', 'takes place in', 'on geographical feature', 'on natural feature', 'is on', 'is in', 'location (terrain feature)', 'loc (terr)'], array([ 0.00746889, -0.0970468 ,  0.00943915, ..., -0.06001402,
#        -0.04440185, -0.01038082], dtype=float32)), (281, 'http://www.wikidata.org/entity/P708', ['diocese'], array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#        -0.06125114, -0.04683771], dtype=float32)), (282, 'http://www.wikidata.org/entity/P725', ['voice actor', 'voice dubber', 'dubbed by', 'VO', 'voiced by', 'CV', 'VA', 'voice actress', 'voice actors', 'voice actresses', 'seiyu'], array([ 0.00746889, -0.11385827,  0.0089396 , ..., -0.06365084,
#        -0.02953678, -0.02067945], dtype=float32)), (283, 'http://www.wikidata.org/entity/P734', ['family name', 'last name', 'has surname', 'surname'], array([ 0.00746889, -0.08167897, -0.03235358, ..., -0.03502839,
#        -0.04005346, -0.02269056], dtype=float32)), (284, 'http://www.wikidata.org/entity/P735', ['given name', 'forename', 'first name', 'personal name', 'middle name', 'Christian name'], array([ 0.00746889, -0.0585707 , -0.00147232, ..., -0.03059936,
#        -0.01797901, -0.0268485 ], dtype=float32)), (285, 'http://www.wikidata.org/entity/P739', ['ammunition', 'cartridge', 'ammo'], array([ 0.00746889, -0.12728208, -0.06788646, ..., -0.07794871,
#        -0.06241924, -0.0385718 ], dtype=float32)), (286, 'http://www.wikidata.org/entity/P740', ['location of formation', 'originates from', 'comes from', 'place of foundation', 'founded in', 'formation location', 'source location of group/organisation', 'formed in', 'from', 'place of formation'], array([ 0.00746889, -0.10447391,  0.00876802, ..., -0.03177325,
#        -0.02938755, -0.01796821], dtype=float32)), (287, 'http://www.wikidata.org/entity/P748', ['appointed by'], array([ 0.00746889, -0.07695843, -0.00368243, ..., -0.0890227 ,
#         0.00246412, -0.02083005], dtype=float32)), (288, 'http://www.wikidata.org/entity/P749', ['parent organization', 'owned by (company or organization)', 'subsidiary of', 'parent company', 'parent organisation', 'owned by (company or organisation)', 'holding', 'holding company', 'part of', 'parent unit', 'parent agency', 'superior formation'], array([ 0.00746889, -0.04419159, -0.00830397, ..., -0.03129605,
#        -0.03521366, -0.01763652], dtype=float32)), (289, 'http://www.wikidata.org/entity/P750', ['distributor', 'distributed by'], array([ 0.00746889, -0.111145  , -0.00757582, ..., -0.07562139,
#        -0.02939352, -0.02847409], dtype=float32)), (290, 'http://www.wikidata.org/entity/P765', ['surface played on'], array([ 0.00746889, -0.10098825, -0.05404265, ..., -0.04552004,
#        -0.05346438, -0.01908506], dtype=float32)), (291, 'http://www.wikidata.org/entity/P767', ['contributor(s) to the creative work', 'assistant', 'contributor', 'collaborator', 'contributor(s) to the subject'], array([ 0.00746889, -0.10006354,  0.00987714, ..., -0.03544185,
#        -0.02434764, -0.03304499], dtype=float32)), (292, 'http://www.wikidata.org/entity/P768', ['electoral district', 'constituency', 'ward', 'riding', 'electoral area', 'electorate'], array([ 0.00746889, -0.12420145, -0.04501472, ..., -0.06236782,
#        -0.04848105, -0.03325652], dtype=float32)), (293, 'http://www.wikidata.org/entity/P769', ['significant drug interaction', 'drug interaction'], array([ 0.00746889, -0.12784249, -0.02798472, ..., -0.07192548,
#         0.01324631, -0.0136589 ], dtype=float32)), (294, 'http://www.wikidata.org/entity/P780', ['symptoms', 'signs'], array([ 0.00746889, -0.09241162, -0.03142235, ..., -0.04179695,
#        -0.05281638, -0.02269132], dtype=float32)), (295, 'http://www.wikidata.org/entity/P790', ['approved by'], array([ 0.00746889, -0.08584135,  0.05684885, ..., -0.04885448,
#         0.01599792,  0.01446875], dtype=float32)), (296, 'http://www.wikidata.org/entity/P793', ['significant event', 'key event', 'key incident', 'significant incident', 'notable event', 'notable incident', 'major event', 'big event', 'main events', 'fate', 'outcome', 'event', 'known for'], array([ 0.00746889, -0.10949964,  0.00639172, ..., -0.07278933,
#        -0.05095717, -0.01797626], dtype=float32)), (297, 'http://www.wikidata.org/entity/P802', ['student', 'students', 'teacher of', 'pupil', 'pupils', 'disciple', 'disciples'], array([ 0.00746889, -0.09887188, -0.00936994, ..., -0.05502438,
#        -0.05438566, -0.03276478], dtype=float32)), (298, 'http://www.wikidata.org/entity/P805', ['statement is subject of', 'article', 'artfor', 'subject of the claim', 'subject of the statement', 'dedicated article', 'subject of', 'dedicated item'], array([ 0.00746889, -0.08175836,  0.0092122 , ..., -0.04478839,
#        -0.03911033, -0.01663896], dtype=float32)), (299, 'http://www.wikidata.org/entity/P812', ['academic major', 'major', 'academic field', 'academic subject', 'subject'], array([ 0.00746889, -0.10039185, -0.00446576, ..., -0.02667372,
#        -0.03279581, -0.01785332], dtype=float32)), (300, 'http://www.wikidata.org/entity/P825', ['dedicated to', 'dedication', 'tribute to', 'dedicatee'], array([ 0.00746889, -0.09987919,  0.0769783 , ..., -0.0568281 ,
#        -0.04738564, -0.0355256 ], dtype=float32)), (301, 'http://www.wikidata.org/entity/P828', ['has cause', 'cause', 'has causes', 'has underlying cause', 'underlying cause', 'ultimate cause', 'ultimate causes', 'initial cause', 'effect of', 'outcome of', 'result of', 'has reason', 'reason', 'caused by', 'implied by', 'because', 'due to'], array([ 0.00746889, -0.07394792, -0.03685539, ..., -0.03094436,
#        -0.04226905, -0.02211624], dtype=float32)), (302, 'http://www.wikidata.org/entity/P837', ['day in year for periodic occurrence', 'day of periodic occurrence', 'day in year', 'day', 'date', 'recurring event', 'periodic occurrence', 'takes place on', 'takes places during'], array([ 0.00746889, -0.0891394 , -0.03334217, ..., -0.03244488,
#        -0.05479202, -0.01625732], dtype=float32)), (303, 'http://www.wikidata.org/entity/P840', ['narrative location', 'setting location', 'narrative set in', 'location of narrative'], array([ 0.00746889, -0.10331039, -0.01727606, ..., -0.05841726,
#        -0.00965441, -0.03016955], dtype=float32)), (304, 'http://www.wikidata.org/entity/P841', ['feast day'], array([ 0.00746889, -0.10223781,  0.00309712, ..., -0.03776111,
#        -0.06475541, -0.00564627], dtype=float32)), (305, 'http://www.wikidata.org/entity/P85', ['anthem', 'national anthem', 'march', 'official song'], array([ 0.00746889, -0.11217664,  0.02019155, ..., -0.04742768,
#        -0.00773858, -0.01813447], dtype=float32)), (306, 'http://www.wikidata.org/entity/P859', ['sponsor', 'funded by', 'funder', 'patron', 'endorsed by'], array([ 0.00746889, -0.11941095, -0.01331328, ..., -0.08598075,
#        -0.02772938, -0.02541546], dtype=float32)), (307, 'http://www.wikidata.org/entity/P870', ['instrumentation'], array([ 0.00746889, -0.14438319, -0.06280058, ..., -0.1044659 ,
#        -0.06125114, -0.04683771], dtype=float32)), (308, 'http://www.wikidata.org/entity/P88', ['commissioned by', 'client', 'commissioner', 'made for', 'built for', 'Developer'], array([ 0.00746889, -0.1034722 , -0.01134579, ..., -0.04971673,
#        -0.0381128 , -0.01505808], dtype=float32)), (309, 'http://www.wikidata.org/entity/P880', ['CPU', 'central processing unit'], array([ 0.00746889, -0.1164088 , -0.03268316, ..., -0.07421964,
#        -0.0546762 , -0.02131584], dtype=float32)), (310, 'http://www.wikidata.org/entity/P915', ['filming location', 'location of filming', 'location where filmed', 'studio where filmed', 'place of filming', 'place where filmed', 'recorded at', 'filmed at', 'shooting location'], array([ 0.00746889, -0.09535197, -0.02371134, ..., -0.03988474,
#        -0.02091144, -0.01753663], dtype=float32)), (311, 'http://www.wikidata.org/entity/P921', ['main subject', 'index term', 'topic of work', 'main topic', 'aboutness', 'about', 'topic', 'subject', 'subject heading', 'mainly about', 'theme', 'main issue', 'main thing', 'keyword', 'is about', 'primary topic', 'primary subject', 'describes'], array([ 0.00746889, -0.08240518, -0.03228536, ..., -0.05303029,
#        -0.04778656, -0.02338589], dtype=float32)), (312, 'http://www.wikidata.org/entity/P931', ['place served by transport hub', 'serves city', 'city served', 'train station serves'], array([ 0.00746889, -0.10535565,  0.05346248, ..., -0.02873763,
#         0.0083831 , -0.01456732], dtype=float32)), (313, 'http://www.wikidata.org/entity/P937', ['work location', 'workplace', 'work location', 'place of activity', 'active in', 'location of work', 'place of work'], array([ 0.00746889, -0.1117745 ,  0.01946465, ..., -0.0470681 ,
#        -0.04148372, -0.02852763], dtype=float32)), (314, 'http://www.wikidata.org/entity/P941', ['inspired by', 'source of inspiration', 'inspiration'], array([ 0.00746889, -0.11124247,  0.04653227, ..., -0.05882928,
#         0.00158732, -0.0297196 ], dtype=float32)), (315, 'http://www.wikidata.org/entity/P97', ['noble title', 'peerage', 'title (hereditary)', 'hereditary title', 'royal title'], array([ 0.00746889, -0.02066112,  0.07023342, ..., -0.01719416,
#        -0.0340033 , -0.04507201], dtype=float32)), (316, 'http://www.wikidata.org/entity/P974', ['tributary'], array([ 0.00746889, -0.13024533, -0.03639873, ..., -0.05730022,
#        -0.04186886, -0.00910007], dtype=float32)), (317, 'http://www.wikidata.org/entity/P98', ['editor', 'compiler', 'edited by', 'compiled by'], array([ 0.00746889, -0.09868953, -0.01042   , ..., -0.07266217,
#         0.00637878, -0.03508582], dtype=float32)), (318, 'http://www.wikidata.org/entity/P991', ['successful candidate', 'elected person', 'winner of election'], array([ 0.00746889, -0.09075499,  0.0326615 , ..., -0.02492922,
#        -0.02665507, -0.02976383], dtype=float32))]

# %% [markdown]
# ### Getting URI of top N topics

# %%
# !!! assuming InferSent has been loaded before
uri_topic_dict = pkl.load(open('uri_topic_dict.pkl', 'rb'))

def getting_most_prob_topics(question, n):
    model = ZS_net(4096).float()
    model.load_state_dict(torch.load('my_model.ckpt'))
    question_embedding = infersent.encode(question, tokenize=True)
    class_probs = np.zeros(len(uri_topic_dict),)
    for i in range(len(uri_topic_dict)):
#         print(question_embedding.shape)
#         print(uri_topic_dict[i][3].shape)
        sim = model(torch.from_numpy(question_embedding).float(), torch.from_numpy(uri_topic_dict[i][3]).unsqueeze(0))
        output = torch.sigmoid(sim)
        class_probs[i] = output.detach().numpy()
    n_best = class_probs.argsort()[-n:][::-1]
    uris = [uri_topic_dict[index][1] for index in n_best]
    return uris

# %%
getting_most_prob_topics(['What is the population of this city?'], 5)
# Out:
# ['http://www.wikidata.org/entity/P1082',
#  'http://www.wikidata.org/entity/P30',
#  'http://www.wikidata.org/entity/P532',
#  'http://www.wikidata.org/entity/P1383',
#  'http://www.wikidata.org/entity/P2046']

# %%
class_probs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-37560df20d0a> in <module>()
# ----> 1 class_probs
#
# NameError: name 'class_probs' is not defined
